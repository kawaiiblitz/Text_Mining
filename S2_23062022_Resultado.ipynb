# %% [markdown]
# # Conexión: S2 & **Profundiza**

# %% [markdown]
# ## Previamenten, en la sesión 01:

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from collections import Counter
from nltk import word_tokenize

tokenize = word_tokenize

contador = Counter(tokenize( 

"¡Feliz cumpleaños, ! Es un honor hacer equipo con mexicanas talentosas como tú honor. ".lower())) 

print(contador)
# Out:
# Counter({'honor': 2, '¡feliz': 1, 'cumpleaños': 1, ',': 1, '!': 1, 'es': 1, 'un': 1, 'hacer': 1, 'equipo': 1, 'con': 1, 'mexicanas': 1, 'talentosas': 1, 'como': 1, 'tú': 1, '.': 1})

# %%
contador.most_common()
# Out:
# [('honor', 2),
#  ('¡feliz', 1),
#  ('cumpleaños', 1),
#  (',', 1),
#  ('!', 1),
#  ('es', 1),
#  ('un', 1),
#  ('hacer', 1),
#  ('equipo', 1),
#  ('con', 1),
#  ('mexicanas', 1),
#  ('talentosas', 1),
#  ('como', 1),
#  ('tú', 1),
#  ('.', 1)]

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import pandas as pd

# %%
contador = Counter("hay momentos en la historia en donde los pueblos se juegan su destino. Hoy es uno de esos momentos.") 

print(contador)
# Out:
# Counter({' ': 18, 'o': 12, 'e': 12, 's': 11, 'n': 8, 'a': 4, 'm': 4, 't': 4, 'd': 4, 'u': 4, 'l': 3, 'i': 3, 'h': 2, 'y': 2, '.': 2, 'r': 1, 'p': 1, 'b': 1, 'j': 1, 'g': 1, 'H': 1})

# %%
stopwords_sp = stopwords.words('spanish')
print(stopwords_sp)
# Out:
# ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se', 'las', 'por', 'un', 'para', 'con', 'no', 'una', 'su', 'al', 'lo', 'como', 'más', 'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí', 'porque', 'esta', 'entre', 'cuando', 'muy', 'sin', 'sobre', 'también', 'me', 'hasta', 'hay', 'donde', 'quien', 'desde', 'todo', 'nos', 'durante', 'todos', 'uno', 'les', 'ni', 'contra', 'otros', 'ese', 'eso', 'ante', 'ellos', 'e', 'esto', 'mí', 'antes', 'algunos', 'qué', 'unos', 'yo', 'otro', 'otras', 'otra', 'él', 'tanto', 'esa', 'estos', 'mucho', 'quienes', 'nada', 'muchos', 'cual', 'poco', 'ella', 'estar', 'estas', 'algunas', 'algo', 'nosotros', 'mi', 'mis', 'tú', 'te', 'ti', 'tu', 'tus', 'ellas', 'nosotras', 'vosotros', 'vosotras', 'os', 'mío', 'mía', 'míos', 'mías', 'tuyo', 'tuya', 'tuyos', 'tuyas', 'suyo', 'suya', 'suyos', 'suyas', 'nuestro', 'nuestra', 'nuestros', 'nuestras', 'vuestro', 'vuestra', 'vuestros', 'vuestras', 'esos', 'esas', 'estoy', 'estás', 'está', 'estamos', 'estáis', 'están', 'esté', 'estés', 'estemos', 'estéis', 'estén', 'estaré', 'estarás', 'estará', 'estaremos', 'estaréis', 'estarán', 'estaría', 'estarías', 'estaríamos', 'estaríais', 'estarían', 'estaba', 'estabas', 'estábamos', 'estabais', 'estaban', 'estuve', 'estuviste', 'estuvo', 'estuvimos', 'estuvisteis', 'estuvieron', 'estuviera', 'estuvieras', 'estuviéramos', 'estuvierais', 'estuvieran', 'estuviese', 'estuvieses', 'estuviésemos', 'estuvieseis', 'estuviesen', 'estando', 'estado', 'estada', 'estados', 'estadas', 'estad', 'he', 'has', 'ha', 'hemos', 'habéis', 'han', 'haya', 'hayas', 'hayamos', 'hayáis', 'hayan', 'habré', 'habrás', 'habrá', 'habremos', 'habréis', 'habrán', 'habría', 'habrías', 'habríamos', 'habríais', 'habrían', 'había', 'habías', 'habíamos', 'habíais', 'habían', 'hube', 'hubiste', 'hubo', 'hubimos', 'hubisteis', 'hubieron', 'hubiera', 'hubieras', 'hubiéramos', 'hubierais', 'hubieran', 'hubiese', 'hubieses', 'hubiésemos', 'hubieseis', 'hubiesen', 'habiendo', 'habido', 'habida', 'habidos', 'habidas', 'soy', 'eres', 'es', 'somos', 'sois', 'son', 'sea', 'seas', 'seamos', 'seáis', 'sean', 'seré', 'serás', 'será', 'seremos', 'seréis', 'serán', 'sería', 'serías', 'seríamos', 'seríais', 'serían', 'era', 'eras', 'éramos', 'erais', 'eran', 'fui', 'fuiste', 'fue', 'fuimos', 'fuisteis', 'fueron', 'fuera', 'fueras', 'fuéramos', 'fuerais', 'fueran', 'fuese', 'fueses', 'fuésemos', 'fueseis', 'fuesen', 'sintiendo', 'sentido', 'sentida', 'sentidos', 'sentidas', 'siente', 'sentid', 'tengo', 'tienes', 'tiene', 'tenemos', 'tenéis', 'tienen', 'tenga', 'tengas', 'tengamos', 'tengáis', 'tengan', 'tendré', 'tendrás', 'tendrá', 'tendremos', 'tendréis', 'tendrán', 'tendría', 'tendrías', 'tendríamos', 'tendríais', 'tendrían', 'tenía', 'tenías', 'teníamos', 'teníais', 'tenían', 'tuve', 'tuviste', 'tuvo', 'tuvimos', 'tuvisteis', 'tuvieron', 'tuviera', 'tuvieras', 'tuviéramos', 'tuvierais', 'tuvieran', 'tuviese', 'tuvieses', 'tuviésemos', 'tuvieseis', 'tuviesen', 'teniendo', 'tenido', 'tenida', 'tenidos', 'tenidas', 'tened']

# %%
stopwords_en = stopwords.words('english')
print(stopwords_en)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
import string

# %%
import string
def quita_puntuacion(texto):
  for caracter in texto:
    if caracter in string.punctuation:
      texto = texto.replace(caracter, '')
  return texto

# %%
quita_puntuacion("hola, no . voy ?")
# Out:
# 'hola no  voy '

# %%
import regex as re
def tokeniza(texto):
    return re.findall(r'[\w]*\p{L}[\w]*', texto)

# %%
def quita_stopword(palabras):
    return [palabra for palabra in palabras if palabra.lower() not in stopwords_sp]

# %%
pipeline = [ quita_puntuacion, str.lower, str.strip, tokeniza, quita_stopword]

def preprocesa_texto(texto, operaciones):
    palabras_temporal = texto
    for funcion in pipeline:
        palabras_temporal = funcion(palabras_temporal)
        
    return palabras_temporal

# %% [markdown]
# ## S2: Construcción de un corpus con otros formatos

# %%
# !unzip /content/datos.zip -d archivos
# Out:
# Archive:  /content/datos.zip
#   inflating: archivos/10.xml
#   inflating: archivos/100.xml
#   inflating: archivos/101.xml
#   inflating: archivos/102.xml
#   inflating: archivos/11.xml
#   inflating: archivos/12.xml
#   inflating: archivos/13.xml
#   inflating: archivos/14.xml
#   inflating: archivos/16.xml
#   inflating: archivos/17.xml
#   inflating: archivos/18.xml
#   inflating: archivos/19.xml
#   inflating: archivos/2.xml
#   inflating: archivos/20.xml
#   inflating: archivos/22.xml
#   inflating: archivos/23.xml
#   inflating: archivos/25.xml
#   inflating: archivos/26.xml
#   inflating: archivos/27.xml
#   inflating: archivos/29.xml
#   inflating: archivos/3.xml
#   inflating: archivos/30.xml
#   inflating: archivos/31.xml
#   inflating: archivos/35.xml
#   inflating: archivos/36.xml
#   inflating: archivos/37.xml
#   inflating: archivos/39.xml
#   inflating: archivos/4.xml
#   inflating: archivos/40.xml
#   inflating: archivos/42.xml
#   inflating: archivos/43.xml
#   inflating: archivos/44.xml
#   inflating: archivos/45.xml
#   inflating: archivos/46.xml
#   inflating: archivos/47.xml
#   inflating: archivos/48.xml
#   inflating: archivos/49.xml
#   inflating: archivos/5.xml
#   inflating: archivos/50.xml
#   inflating: archivos/51.xml
#   inflating: archivos/52.xml
#   inflating: archivos/53.xml
#   inflating: archivos/54.xml
#   inflating: archivos/55.xml
#   inflating: archivos/56.xml
#   inflating: archivos/6.xml
#   inflating: archivos/61.xml
#   inflating: archivos/62.xml
#   inflating: archivos/63.xml
#   inflating: archivos/64.xml
#   inflating: archivos/65.xml
#   inflating: archivos/66.xml
#   inflating: archivos/67.xml
#   inflating: archivos/68.xml
#   inflating: archivos/69.xml
#   inflating: archivos/7.xml
#   inflating: archivos/70.xml
#   inflating: archivos/71.xml
#   inflating: archivos/72.xml
#   inflating: archivos/73.xml
#   inflating: archivos/74.xml
#   inflating: archivos/75.xml
#   inflating: archivos/77.xml
#   inflating: archivos/78.xml
#   inflating: archivos/8.xml
#   inflating: archivos/81.xml
#   inflating: archivos/82.xml
#   inflating: archivos/83.xml
#   inflating: archivos/84.xml
#   inflating: archivos/85.xml
#   inflating: archivos/86.xml
#   inflating: archivos/87.xml
#   inflating: archivos/88.xml
#   inflating: archivos/89.xml
#   inflating: archivos/90.xml
#   inflating: archivos/91.xml
#   inflating: archivos/92.xml
#   inflating: archivos/93.xml
#   inflating: archivos/94.xml
#   inflating: archivos/95.xml
#   inflating: archivos/96.xml
#   inflating: archivos/97.xml
#   inflating: archivos/98.xml

# %%
import xml.etree.ElementTree as et
import os

# %%
reviews_textos = []
for archivo in os.listdir("/content/archivos"):
    archivo_abierto = open("/content/archivos/" + archivo,
                           'r', errors='ignore').read()
    oxml = et.XML(archivo_abierto)
    reviews_textos.append(oxml[1].text)

# %%
reviews_textos[0:12]
# Out:
# ['El cine asitico se ha convertido ya en lo que el conjunto de sus pases de origen, en un gigante. Esta semana se estrena en Espaa con gran expectacin la adaptacin del best-seller Memorias de una geisha. Y, desde luego, es una superproduccin en toda regla, sobre todo por el hecho de que el director es el que rod Chicago (a puntito estuvieron Spielberg o Spike Jonze) y porque la factura es norteamericana. Y adems, incluye en su reparto a las estrellas cinematogrficas de ms relumbrn: Li Gong, Michelle Yeoh, Ziyi Zhang y Ken Watanabe. Por cierto, que slo l es japons, porque la gran Yeoh naci en Malaysia y las otras dos en la milenaria China. Curioso. Tambin aparecen por ah Cary-Hiroyuki Tagawa, Kji Yakusho y Randall Duk Kim, que seguro que los han visto en alguna que otra peli.La recreacin del Japn de los aos 30 y 40 es fantstica, y eso que es todo decorado menos, creo, los jardines del saln de t, una explosin de colorido y paz (s, la filosofa Zen me ha invadido). Y la historia es casi pica. En realidad, es una historia de amor ms que una biografa desgraciada, con la que es de sobra conocido que la propia y real protagonista, Mineko Iwasaki, no congraciaba, por lo que decidi escribir posteriormente su propia versin. Es interesante, no obstante, contemplar cmo la cultura tan arraigada mueve la cotidianeidad de las mujeres desde que son unas nias y cmo estas se preparan para ser las ms deseadas y envidiadas. Porque tambin se muestra la codicia y la decrepitud que en un momento dado invade los corazones de las damas. Todo muy metafrico, muy retrico y muy adornado, ya se pueden imaginar. Pero bien agradable y sin resultar pesado, que es verdad que algunas producciones orientales pecan de ello.As que, a pesar de algn que otro cabo suelto y de lo apabullante y poco sobrio que resulta en ocasiones el desarrollo de la narracin (por cierto, en voz en off, un recurso muy resolutivo), no pongo demasiadas objeciones a Memorias de una geisha. Y desde luego, las actrices me han gustado una vez ms. Guapas como ellas solas. Al seor Watanabe se le ve mayor, qu le vamos a hacer.Si quieren apreciar algo ms este mundo misterioso, dos consejos. My dear Moriarty me ha recomendado encarecidamente que vea Zatoichi, del insigne (dice l) Takeshi Kitano. Al que, hablando de otra cosa, volveremos a ver pronto en una de sus facetas ms alocadas, segn dice Gadxeto blog. Y una cosa ms: si pueden, contemplen un da las tradiciones japonesas ms ancestrales, como la ceremonia del t o la colocacin de un kimono (gracias a Sony). Nada ms. ',
#  'Es curioso observar cmo hasta el propio cine se debate entre diferentes pseudo-oleadas convertidas en moda temporal. Basta que uno lance la primera piedra para que la pantalla se convierta en un apedreamiento masivo. Como todo en este mundo, tiene sus pros y sus contras."Transamerica" juega un poco con todos esos factores que rodean a las ideas supuestamente repentinas, innovadoras, atrevidas y rompedoras. Pero, como lo que prima en la calidad cinematogrfica son otros factores. sale un poco malparada. En primer lugar, los que piensen que el film es terriblemente original por, solamente, tratar de cerca el tema de un transexual, estn muy equivocados. Ni siquiera es el verdadero trasfondo de la pelcula.Lo que s que se agradece es el atrevimiento y el desenfado con el que se toca un tema tan (posiblemente) controvertido y polmico. Pero esa es un arma de doble filo. Lo que en un principio es una especie de road-movie al uso (pero absolutamente con todos los factores vistos y manidos) con tono cmico y cierto trasfondo dramtico, degenera en un sucedneo de comedieta de enredo familiar ciertamente pattico, y concluye, lgicamente, como un drama aderezado con pequeos elementos cmicos para entretener al espectador.Una evolucin tan ordenada como evidente y previsible. El problema es que es un drama tan simple y tpico, cientos de veces visto en cine, que necesita una mscara divertida que lo haga un tanto entraable. Y esa mscara, precisamente, es la que evita que la historia est contada con la garra necesaria como para que nos pongamos en la piel de Stanley/Sabrina con toda la seriedad que lo requiere.Como deca, ese desenfado con el que se nos habla de un tema tan complicado para muchos es un punto a favor, y, realmente, puede ser as si simplemente buscas diversin en el cine. Pero viendo su escasa originalidad, es complicado ascender a la pelcula ms all de un entretenimiento pasajero.Tenemos todos los ingredientes de las road-movies tragicmicas. La frustracin de un padre/madre al descubrir la existencia de un hijo, hasta el da de hoy, desconocido. Las casualidades que dan lugar, obviamente, a que ambos coincidan y se conozcan. El viaje que emprenden, que ms que un viaje es un claro McGuffin para una futura redencin y un redescubrimiento de ambos.Un viaje ms espiritual que fsico, un viaje en el que, por mucho que Stanley/Sabrina busque el elemento que le convertir definitivamente en la mujer que siempre ha querido ser, lo nico que realmente buscar es la aceptacin y el encuentro con su hijo. La historia de redencin que en esencia es, no hace ms que inundar al espectador en una continua sensacin de "dj vu". Los secretos inconfesables que se van descubriendo a lo largo del viaje, los traumas de la infancia que se reavivan por la intolerancia vivida frente a una opcin sexual (o psicolgica, no voy a ponerme a analizarlo) atpica, tanto en el entorno familiar como en el entorno social. El miedo al rechazo y al reemplazo de un hijo al que no se le dio todo el cario requerido por su condicin de transexual (aqu es el tema que nos trata, pero cualquier otro motivo o condicin es vlido y aplicable).Todo un cmulo de evidencias que encarecen en demasa la calidad y originalidad del producto final.Porque no, no nos engaemos. El que se nos cuente la historia de un transexual no cambia nada. Si fuera un drogadicto, un hijo perdido, un cobarde que se va de casa porque todo se complica, o un maltratador, seguramente el film no alcanzara tales cotas de inters pblico. Pasara desapercibido, ya que es realmente lo que merecera.La historia es la de siempre. Lo nico que cambia es la opcin sexual de su protagonista. Pero no. Hay que aceptar que es la historia de un transexual y que por ello habr revuelo. Y crticas injustas. Son cosas que pasan. Si por ese simple motivo tenemos que tildarla de peliculn, olvidndonos de su verdadera calidad y haciendo ms caso al revuelo que provoca. yo no me subir a ese carro.Asimismo, Felicity Huffman est bien, pero para nada tan genia ...
#  'Es que no la cagan en ninguna, todas las pelis que hacen son cada vez mejores. Incluso no caen en los estereotipos en los que es tan fcil caer, que es repetirse y repetirse, como la mierda de American Pie 3, que es volver a hacer los mismos chistes, mal contados y previsibles a la milla. Qu se esconde detrs de esas peliculas? Cmo es que no te aburren ni un solo momento? Cmo es que entretienen por igual a nios que a mayores? No tengo ni puta idea, lanzo las preguntas al aire, si alguien las sabe, que las responda ahora mismo en alto en su casa. Esta vez me ha pasado algo que no me habia pasado nunca antes con una pelicula (bueno si, con Pocahontas un poquito). Y es que la madre y la nia me han puesto brutito. La madre al comienzo de la pelicula esta quesito, ella toda mona, y luego al final de la peli cuando se pone en plan luchadora tambien, en cambio cuando esta de madre es el bajon de pene total. La hijita al principio mola asi en plan siniestra pseudo freak. Pero no pa follar todavia, solo para darle apretones y muerdos. Es despues, cuando se echa to el pelo pa los laos cuando esta para hacer maldades. Por qu veo hasta en los dibujos animados posibles fminas dispuestas para el apareamiento? Por qu me pone la mujer por ser mujer, tanto al natural, en pelicula o en dibujo animado? Supongo que es un defecto fisico propio de mi hobbie por leer comics eroticos. Son dibujitos, si, pero te ponen como motos acuaticas, echando espuma de agua por todos los lados. Joder, yo quiero ver la segunda parte de los Increibles, y la tercera. Por que coo no hacen mas de ese tipo de pelis y se dejan de tanto coazo de tiros, asesinos en serie, polis malos y buenos, desastres naturales donde todos se salvan, dramones aburridos, comedietas que no hacen reir, superheroes que no cuentan nada, y mil y una pelis para adolescentes que es como para matarlos a todos? Hagan mas pelis asi! Y a ser posible con mas tias buenas! En esta peli hay una frase que me encanta, que es cuando el padre le dice a la madre, que qu mania tienen los yankis en engrandecer y festejar continuamente la mediocridad. En referencia a ir a la fiesta de fin de curso o eso que hacen los yankis cuando acaban los estudios, en mi cole se llamaba fiesta de fin de curso. Alli daban diplomas creo. Pues eso, id a ver esa gran pelicula que es divertida, ingeniosa, con mucha accion y entreteniemiento. Que para una vez que sacan una peli que esta bien, hay que decirlo! ',
#  '"Los 100 golpes", as se llama el polmico y exitoso libro que autobiograficamente escribi Melissa Panarello, una joven italiana que ahora ronda los 19 aos. Dicho libro trajo consigo el escandalo al relatar la vida sexual de esta chica cuando tan solo contaba con 15 y 16 aos. Y es que este no es un cuento del despertar sexual a lo "Verano del 42", es un espejo de la sociedad actual, en la que el sexo ha dejado de ser un juego de adultos para ser un juego de nios, con los riesgos psiquicos y fsicos que esto puede conllevar.Esto es lo que se intenta transmitir en la versin cinematogrfica de "Melissa P.", en donde el sexo con todas sus variantes es descubierto por la joven Melissa, cuando su inocencia y su ingenuidad todavia estn a flor de piel.Para esta Lolita del siglo XXI, los italianos han importado a la Lolita espaola, Maria Valverde, la actriz que se dio a conocer y gan un Goya por aquella estupenda pelcula de Manuel Martn Cuenca titulada "La flaqueza del bolchevique", en la que supo dar a su personaje la dulzura y descaro necesarios. Todo un descubrimiento en aquella pelcula, donde apenas tenia 16 aos, Valverde se ha convertido en una de las ms prometedoras actrices de nuestro cine. Esperemos que su rostro aiado e inocente no sea flor de un da y que con los aos sepa afrontar papeles que no sean el de nia provocativa. Que pueda acoplarse a papeles adultos.En esta ocasin, su papel vuelve a requerir gestos infantiles con actitudes maduras. Valverde convence en su inocencia, pero no tanto en su contacto con los personajes adultos. Hubo que esperar a que Valverde cumpliese los 18 aos para que pudiese rodar las escenas de desnudos y lo cierto es que no han escatimado en secuencias de este tipo, necesarias por otro lado, para contar una historia, que no es sino, un diario sexual con todas sus consecuencias. Adems el doblaje de la propia Maria Valverde, le hace un flaco favor en su versin espaola.Lo verdaderamente interesante de esta "Melissa P.", aunque nada nuevo por otro lado, es algo que ya contenia la novela. Ese espejo, como decimos, en que puede mirarse una gran parte de la juventud ms temprana. El sexo y sus consecuencias en un nio que todavia usa mochilas y acaba de dejar de jugar con sus juguetes. El trastorno psquico que ello puede conllevar en la persona. Para reafirmar la fragilidad de la nia, la cinta introduce dos personajes y uno fantasma, alrededor de Melissa. Una madre que cree que le da todo a su hija, pero que en realidad apenas la conoce, una abuela que entiende a la joven, pero que no vivir en su casa para aconsejarla y un padre inexistente con el que Melissa, solo se comunica por SMS.Por tanto un retrato en donde vemos a una quinceaera, sin una ayuda patenal o maternal, sin ese bsico entorno familiar que es necesario para una correcta socializacin de un ser humano. Una casa en donde abunda la soledad. Y en cuanto al ambito del Instituto, buenas y malas influencias son mostradas en la cinta. La eleccin de unas u otras por parte de Melissa, la llevarn a un infierno de sexo descontrolado o al camino recto que corresponde a su edad.En cuanto a lo estrictamente cinematogrfico de "Melissa P.", poco podemos salvar o destacar. Lo interesante y anteriormente citado,ya era la base del libro, y, como no podia ser de otro modo, se mantiene en la cinta. Pero el resto parece sacado de un telefilm de medio pelo, que ni las cadenas ms proclives al telefilm seleccionarian para su parrilla.Una direccin sin tacto, sin gusto. Un montaje psimo y una malisima utilizacin de la msica.Luca Guadagnino, el director de la funcin, se queda a medio camino entre el tono poetico y el tono sordido. Introduce personajes de los que se olvida facilmente para luego introducirlos de nuevo en pantalla sin previo aviso. Adems algunas secuencias sexuales estn rodadas sin el ms mnimo talento. Y lo ms preocupante, a veces da la sensacin de que estamos ante un anuncio de compresas.No hay nada con una mnima relevancia en "Melissa P.". Un relato nada es ...
#  'Una Historia Violenta, 2005, es verdaderamente VIOLENTA. Nunca mejor puesto un ttulo. Por favor, no se les ocurra ir con sus sobrinos menores de 10 aos porque los dejaran para terapia psiquitrica unos cinco aos por lo menos. Muerte y sexo explcito y en close up. Pero aparte de vioLENTA es LENTA. Tan lenta que en muchas partes resulta asfixiante. Es decir, la pelcula causa stress, porque entre que no pasa nada o pasan las cosas ms crueles de un momento a otro.Fui a verla con demasiadas expectativas, pues estaba promocionada como uno de los mejores estrenos del ao, fuerte candidata al Globo de Oro, etc. Pero nada que ver. Las actuaciones de la mayora del reparto resultan inocentonas y poco profesionales. Psimo casting. La actuacin del protagonista, Viggo Mortensen (El Seor de los Anillos, 2001-2003) s es buena, al igual que las de los recorridos actores Ed Harris (Las Horas, 2002) y William Hurt (Inteligencia Artificial, 2001). Pero el resto del elenco?',
#  'Algunas me odiaran sin dilacin por arremeter contra una peli del guapo Clooney, algunos por no entender el mensaje liberal y crtico de la cinta, y otros por no saber apreciar el gusto de una pelcula rodada en blanco y negro al estilo clsico, o por no claudicar ante su actual reconocimiento en Hollywood. La tensin y el rigor dramtico de la pelcula brillan por su ausencia. La cmara, efectivamente cuenta la historia en blanco y negro, pero no es "La lista de Schindler" ni muchsimo menos y, en esta, el lenguaje cinematogrfico y la puesta en escena no pasan de mediocre.Los actores hacen buenamente lo que pueden con un guin plano, tedioso y predecible. David Strathairm posa muy serio todo el tiempo, con la sobriedad suficiente. Clooney aparece muy elegante, muy correctito y nada ms. Y la historia entre Robert Downey Jr y Patricia Clarkson pasa tan desapercibida, que no llega a otra cosa que a resultar absurda. Los actores fuman, eso s, mucho, que ya se sabe que en el cine clsico de Bogart ya quedaba muy bien y adems, para tratar de ir an ms a la contra, que mejor que exaltar el consumo del tabaco en una sociedad en la que actualmente se apunta a dejar el hbito.La televisin puede ser un instrumento para educar o para evadir. La televisin es manipulable. Ya, si, y qu? Pues eso, nada ms. Ni un atreverse a retratar realmente la caza de brujas, ni la era Mc Carthy, ni arriesgarse a abordar una critica sincera, seria o interesante sobre nada de nada. "Buenas noches y buena suerte" es un pestio espectacular. El que se sentaba en el cine a mi lado, tras los veinte primeros minutos, se durmi como un beb y despus sobrevivi el ansiado final enchufndose a su mp3. Yo le envidi por ello, aunque decid vrmela hasta el final, aunque fuese nicamente para poder escribir sobre ella hoy aqu. Qu enorme desilusin con una pelcula de la que esperaba muchsimo ms. Lo mejor, sin duda alguna, fue que, gracias a Dios, el suplicio no super la hora y media.',
#  'La llave del mal no es mala pelcula, pero decepciona si vas a ver una peli de terror. La presentacin de la casa y de los personajes principales se hace muy larga y aburrida y adems el tema de la brujera y el vud no est del todo bien representado. En la pelcula se nota cierta visin sesgada del fenmeno de la brujera, con un tufo americano a la serie "embrujadas" que tira para atrs, sobre todo al final de la pelcula. Encima se inventan el rollo ese del jud que es igual que el vud pero nacido en Nueva Orleans. Qu diferencia hay entre el vud y el jud? Pues ninguna, as de claro.Es cierto que la pelcula se hace pesada en muchos tramos, pero hay que reconocer que en otros la historia recobra inters y algo de intensidad. El personaje que mejor sale parado en la llave del mal es la mujer anciana cuya persecucin arrastrndose por el pasillo es lo ms destacable y "terrorfico" de la pelcula. A pesar de que el final es totalmente predecible, al final "triunfa el mal", cosa de agradecer ultimamente con tanto guin pasteln.Hay muchas cosas que no encajan en esta pelcula y una de ellas es la relacin de la joven protagonista con el anciano. Tampoco se explica muy bien la locura transitoria de la protagonista al final de la pelcula que la ciega a actuar como una energmena. Se aprecia mucha diferencia entre la cordura que muestra la joven al principio y la ltima escena del espejo. El director, Iain Softley, incurre en muchos tpicos del gnero como la casa encantada, las puertas, cerrojos y llaves, ruidos, antesustos-sustos para llevarnos a un climax final en el que puede ms la accin que el terror.En definitiva, la llave del mal es un buen thriller paranormal pero que no consigue hacer sombra a la gloriosa "The ring" del mismo guionista.',
#  'No es ninguna novedad que los productos de cine made in USA estn en horas bajas. Slo hay un puado de ttulos que consiguen sacarnos del aburrimiento que suelen producirnos los remakes, las ensaladas de clichs y el cine ms comercial. Estos ttulos suelen venir de directores ms o menos noveles, ya que son pocos los dioses del cine capaces de hacer algo diferente. Este es el caso de Crash y su director, Paul Haggis, que viene del mundo de la televisin y ha debutado con esta pelcula que rod durante 2003 (despus de haber escrito el guin de Million Dollar Baby). Crash se sita en Los ngeles, una de las ciudades con mayor mezcla racial de Estados Unidos (y puede que del mundo). Esta mezcla provoca conflictos a diario entre blancos, negros pobres, negros ricos, rabes, hispanos, orientales,. Se trata de comunidades con muchas diferencias que se ven obligadas a compartir un mismo espacio vital y a sobrevivir da a da frente a las adversidades. Los protagonistas de Crash son estereotipos andantes: los hermanos negros, dedicados al crimen; la pareja de policas blancos, uno de ellos racista y el otro no; el rabe, que no est dispuesto a integrarse a la cultura occidental; el negro rico, que puede ser ms racista que un blanco; el poltico blanco, que slo ve a la comunidad negra como un saco de votos. Todos ellos vivirn historias diferentes que en algn momento se cruzarn en algn punto de las calles de Los ngeles. Segn la situacin, cada uno de ellos dar lo peor o lo mejor que llevan dentro, con lo que el director parece querer decir que entre personas distintas son tantas las cosas que les unen como las que les separan. Estticamente, Crash recuerda mucho a Traffic, con la que tambin comparte el ritmo y el desarrollo de las distintas historias. Aunque algunas interpretaciones son destacables, especialmente las de Matt Dilon en el papel de polica y Don Cheadle en el de detective, el punto fuerte de esta pelcula es el guin (no en vano Higgis tienes ms tablas como guionista que como director). Si hay que ponerle un pero a ste, es que arranca con un realismo crudo y va transformndose en una historia de casi final feliz ms endulzada, perdiendo parte de la credibilidad en el camino. Crash es de lo mejor que ha pasado por los cines este ao y toca un tema que cada vez tiene ms actualidad en nuestras sociedades: la mezcla racial y de culturas. Paul Haggis muestra con habilidad que son muchas las diferencias que nos separan, pero que a cierto nivel son tambin muchas las cosas que compartimos y que deben ser el punto de partida para avanzar en la direccin correcta. En fin, una pelcula con una sutil moralina que quizs podra haber mantenido el nivel de realismo con el que arranca, pero que en cualquier caso mantiene el inters hasta el final con bastante solvencia, que no es poco.',
#  'Otro remake americano que se estrena entre nosotros, que oh sorpresa! no es de una pelcula oriental de terror. Esta vez han cogido un film del excelente director John Carpenter, ?La Niebla?, realizado en 1980, y que a pesar de un par de ideas buenas, considero que es una de sus peores pelculas. Creo que era un film muy desaprovechado, asi que cuando me enter de que estaba en marcha una nueva puesta al da de la pelcula, pens que tal vez explotaran mejor el excelente material que haba entre manos, obra del mismo Carpenter, y de su eterna socia, recientemente fallecida, Debra Hill. Sin embargo, cuando se dio la noticia de que el director iba a ser Rupert Wainwright, perd toda esperanza, y me ech a temblar, porque todava me despierto sudoroso, por las noches, recordando aquel espantoso bodrio llamado ?Stigmata?. ?No puede hacerlo peor?, me repeta una y otra vez. Pues s. S que puede, y despus de ver la pelcula, slo puedo decir que convierte a la de Carpenter en una obra maestra.En un pueblecito costero, muy mono, que est en una isla ms mona todava, un montn de personajes monos, deambulan por sus vidas monas, cuando de repente, una densa y mona niebla, empieza a cargarse a algunos, porque resulta que la isla oculta un terrorfico pasado. Y no, no es porque haya un mono.Intentando renovar la versin anterior, han querido hacerlo en todos los aspectos posibles. Incluso rejuveneciendo a algunos de sus personajes principales. Para ello han echado mano de dos de los actores ms famosos en el actual panorama televisivo. Por un lado, Tom Welling, intrprete de ?Smallville? (serie de la que no he visto ni un slo episodio, qu tal est?), y por otro, Maggie Grace, una de las protagonistas de la? espera, espera, que ah va vuestra palabra favorita, s o b r e v a l o r a d a ?Lost?, aunque eso s, muy entretenida. Lo dos estn? es que no estn, porque sus personajes no son nada, no existen; arquetipos de arquetipos del tpico. La tercera en discordia es mi adorada Selma Blair, una actriz con un morbo especial, pero que aqu tampoco est, no existe, no es nada, ya que no hay nada? de nada? Dios moooo!! la nieblaaaaaa? !!?he escogido un mal da para dejar de oler pegamento. A qu no sabeis de qu pelcula es esa frase? qu pasa? no entendeis lo que estais leyendo? Es que la pelcula no tiene sentido. Pues la crtica tampoco. Y prefiero hablar de otras cosas? Qu tal est la quinta temporada de ?24?? No conteis nada, que todava no he empezado a verla, y yo soy un fan de Jack Bauer, bueno de las tres primeras, porque el churro de la cuarta, no vala ni pa mojar en chocolate? Estoy pensando en el meme sobre hbitos extraos que me han pasado, pero eso lo dejo para mi blog, donde me permito hacer un poco de trampa, y trasladarlos al mundo del cine?Bueno, venga, voy a centrarme. Ya est, ya estoy centrado, pasmela, pasmela? En la silla de director, y pintando la mona, Rupert Wainwright, al que algn enemigo personal le recomend que se dedicase al mundo del cine. La realizacin de este film no slo es enormemente plana, si no que est lleno de torpezas, y eleva los tpicos a la ensima potencia, provocando en algn momento, concretamente dos, la carcajada. En el resto, se sufre, y no precisamente de terror. Wainwright cree que con rodar primeros planos, y luego alternarlos con un montaje efectista, ms efectos de sonido absurdos, va a provocar algn tipo de suspense o tensin, o intranqulidad, o sabe Dios qu. Qu??La pelcula est llena de momentos ridculos, y adolece de la maldita mana de querer explicarlo todo, con lo que algunas cosas son simplemente vergonzosas, por increbles. Si algo tena de bueno el film de Carpenter, era que los aspectos ms interesantes del relato eran sugeridos, y quedaban a la imaginacin del espectador. Aqu no hay nada de eso, por lo que, intentando no dejar ningn cabo suelto, se suceden una serie de situaciones ilgicas, y el resultado es peor. Y si no, de lo mal explicado y mostrado que est, cmo es posible que en el pasado (y no es ningn spoiler) esas cuatro pe ...
#  'Por fin he podido ver "Brokeback Mountain", la laureada y alabada pelcula de Ang Lee. El film que todo el mundo esperaba tras triunfar en el Festival de Venecia, en un gran numero de premios de la crtica estadounidense, en los Globos de Oro y casi con toda seguridad en los Oscars, si nada ni nadie lo remedia. "Brokeback Mountain" me parece, desde ya mismo, la pelcula ms sobrevalorada que ha dado el cine en los ltimos aos. Y ms que me lo parecer si consigue la mxima estatuilla.El visionado de esta pelcula de paisajes y pastores, me ha defraudado. Y que conste que he juzgado a este terreno vedado de la manera ms objetiva posible, sin atenerme a la gran cantidad de premios que le han otorgado hasta la fecha y sin pararme a pensar lo que representa a mi juicio la carrera del realizador Ang Lee.El director taiwanes tiene hasta la fecha una soprendente filmografa, tan dispar como imprevisible, capaz de hacer "Sentido y Sensibilidad" y "La tormenta de hielo" y al mismo tiempo ese arrebato marcial que era "Tigre y Dragon" o una cinta de superheroes para el sistema hollywoodiense como "Hulk".Y es que Ang Lee demuestra no tener ese poder que tiene Clint Eastwood para contar historias sensibles, con extrema lentitud y que te parezcan maravillosas. Y eso que aqu lo intenta, pero consigue que esta historia de amor entre los dos vaqueros sea tediosa, insufrible y larga. "Brokeback Mountain" narra una historia de amores incomprendidos, de amores imposibles. Eso ya lo he visto muchas veces antes y con una mayor pasin e inters en un gran numero de pelculas. Citar un ejemplo, en el cual no me alejo de lo rural, de la poca de ambientacin y del ritmo; "Los puentes de Madison" de Clint Eastwood, que me parece clave, como comparacin a la hora de juzgar definitivamente como obra mayor a la cinta de Lee. Solo algunas miradas entre Meryl Streep y Clint Eastwood en esta pelcula ya contienen mayores dosis de pasin que las dos horas y cuarto de los vaqueros de la montaa.Y es que independientemente de que "Brokeback Mountain" sea una historia homosexual, heterosexual o lo que sea, es ante todo una historia de amor que no transmite ni un ligero sentimiento al espectador.La historia de "Brokeback Mountain" nunca llega a enternecer porque en ningn momento consigue transmitir ese caracter de relacin que, en parte, no llega a ser consumada por cuestiones o prejuicios sociales. Las pocas pinceladas que da Ang Lee, sobre el miedo que pueda existir en los personajes sobre la relacin, son escasas para convencernos.Adems los protagonistas estan sumamente flojos en sus interpretaciones. Ledger y Gyllenhall estn inexpresivos. Nunca sabes que estn pensando, cuales son sus intenciones, y no basta con poner cara de cabreado o de enojado. Enormemente flojos en sus papeles. Solo salvaria a la sumisa esposa, Michelle Williams, que tiene el mejor plano de la pelcula, cuando descubre a su marido besandose con Jake Smith.Como igualmente flojo es su guin, muy plano, que esboza apenas unas notas de todo este largo metraje que transcurre entre ovejas, montaas y encuentros esporadicos, sin desarrollar ninguna de las subtramas, sin que ninguna de ellas capte la atencin. La labor, por tanto, es totalmente de la direccin, que pone en la practica esta escasa teoria que ofrece su guin, alargando lo ms posible los encuentros de sus protagonistas, que se repiten una y otra vez para tedio del espectador.Y es que cuando los paisajes te parecen ms bonitos e interesantes que la historia de amor que se esta contando, es que algo no funciona. Falla la pasin, falla la emocin, falla lo conmovedor. Y eso es sumamente importante en una pelcula a la que se le est otorgando el calificativo de obra maestra con suma facilidad."Brokeback Mountain" me ha sabido a poco, incluso a pelcula desaprovechada. Cierto es que Ang Lee no pretende hacer un alegato en favor de la homosexualidad, solo contar una historia romntica, pero si que apunta algunas pequeas pinceladas de la no aceptacin social que nunca ll ...
#  'Advertencia a todos mis lectores, no vayan al cine a ver esta pelcula, que es un truo gigante. Avisados quedais. Alone in the dark proviene, el ttulo de un juego que sali para PC hace una pila de aos. Fue una novedad absoluta, adems de una revolucin. Tena un buen guion, unos grficos tridimensionales y un sistema de cmaras que era la caa. Pues esta pelcula slo se parece al juego en el nombre.La pelcula trata de un hombre que vivi unos extraos experimentos durante su infancia en el horfanato, hasta que sufri una descarga elctrica, que en vez de materle como debera ser, hizo nacer el engendro de pelcula esta. Aos despus, nos cuentan que estn tras la bsqueda de artefactos dejados por una antigua civilizacin pre-americana (de cuando esto era una pangea, ms o menos) que haban contactado con otros mundos y no se que vainas ms. Total, que luego salen unos bichos que se comen a los humanos, y estos se defienden y mueren y explota todo y se termina y tu respiras. Pero luego sigue y te quieres cortar las venas, y cuando parece que no ha terminado, va y termina. Increble.Que quereis que os diga ms? Efectillos especiales sin guin y accin sin ton ni son. Actores tontsimos que actan sin coherencia alguna. Y lo peor de todo, ms all del final dantesco, es la escena de sexo. Quien folla con los calzoncillos? Que mujer lo hace con sujetador? Vamos hombre, darle alegra a la vida, que no os importa sacar escenas hiperviolentas de muerte y destruccin pero no sacais "chicha".',
#  'Lo que primero llama la atencion de Zathura es su similitud con Jumanji, lo cual no es raro ya que supuestamente esta pelicula iba a ser Jumanji 2 pero cuando ya no consiguieron a los actores de la primera parte decidieron seguir con la pelicula como si fuera independiente aunque an la asociacin es patente, de hecho la gran diferencia entre las dos es que Jumanji posea cierta historia y esta pelicula es mas bien una sucesin de aventuras con una sorpresa final que hace que la pelicula mejore bastante.Esta vez dos hermanos son dejados una tarde solos en casa por su padre bajo el cuidado de su hermana adolescente que slo duerme, en una pelea el mas pequeo encuentra en el stano el juego Zathura y convence a su hermano mayor para jugar. Para su sorpresa al empezar el juego su casa aparece en medio del espacio donde debern seguir jugando enfrentndose a extraterrestres, meteoritos y robots para volver a casa y dejar de lado sus diferencias.Zathura tiene cierto parentesco con pelculas infantiles de mi poca en ese sentido apela bastante a la nostalgia lo cual podria hacerla disfrutable con personas ms adultas sin embargo es principalmente una pelcula de aventuras para nios y bastante entretenida, aun cuando el guin slo sea una acumulacion de episodios tras otros hasta el final donde hay un descubrimiento que pone la pelicula en perspectiva y le da algo de calidez y un mensaje, simple pero mensaje al fin y al cabo.']

# %%
corpus = pd.DataFrame(reviews_textos, columns=['reviews'])

# %%
corpus.head(5)
# Out:
#                                              reviews
# 0  El cine asitico se ha convertido ya en lo que ...
# 1  Es curioso observar cmo hasta el propio cine s...
# 2  Es que no la cagan en ninguna, todas las pelis...
# 3  "Los 100 golpes", as se llama el polmico y exi...
# 4  Una Historia Violenta, 2005, es verdaderamente...

# %%
corpus['tokens'] = corpus['reviews'].apply(preprocesa_texto, operaciones=pipeline)
corpus.head()
# Out:
#                                              reviews  \
# 0  El cine asitico se ha convertido ya en lo que ...
# 1  Es curioso observar cmo hasta el propio cine s...
# 2  Es que no la cagan en ninguna, todas las pelis...
# 3  "Los 100 golpes", as se llama el polmico y exi...
# 4  Una Historia Violenta, 2005, es verdaderamente...
#
#                                               tokens
# 0  [cine, asitico, convertido, conjunto, pases, o...
# 1  [curioso, observar, cmo, propio, cine, debate,...
# 2  [cagan, ninguna, todas, pelis, hacen, cada, ve...
# 3  [golpes, as, llama, polmico, exitoso, libro, a...
# 4  [historia, violenta, verdaderamente, violenta,...

# %%
len(corpus)
# Out:
# 83

# %%
corpus.describe()
# Out:
#                                                   reviews  \
# count                                                  83
# unique                                                 83
# top     El cine asitico se ha convertido ya en lo que ...
# freq                                                    1
#
#                                                    tokens
# count                                                  83
# unique                                                 83
# top     [cine, asitico, convertido, conjunto, pases, o...
# freq                                                    1

# %%
corpus.shape
# Out:
# (83, 2)

# %%
corpus_palabras = []
corpus_palabras = list(i for j in corpus.tokens.to_list() for i in j)

# %%
len(corpus_palabras)
# Out:
# 21784

# %%
corpus_palabras[0:15]
# Out:
# ['cine',
#  'asitico',
#  'convertido',
#  'conjunto',
#  'pases',
#  'origen',
#  'gigante',
#  'semana',
#  'estrena',
#  'espaa',
#  'gran',
#  'expectacin',
#  'adaptacin',
#  'bestseller',
#  'memorias']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
def nube_palabras(corpus, stopwords, color):
    stopwords = set(stopwords)
    wordcloud = WordCloud(
        background_color=color,
        stopwords=stopwords,
        max_words=100,
        max_font_size=45,
        scale=3,
        random_state=1)
   
    wordcloud=wordcloud.generate(str(corpus))

    fig = plt.figure(1, figsize=(15, 15))
    plt.imshow(wordcloud)
    plt.show()

# %%
nube_palabras(corpus_palabras, stopwords_sp, '#b9d5fd')

# %%
json_df = pd.read_json("https://raw.githubusercontent.com/tutsplus/train-a-text-classification-model-with-create-ml/master/sentiment_analysis.json")

# %%
json_df.head()
# Out:
#   label                                               text
# 0   Pos  Now all @Apple has to do is get swype on the i...
# 1   Pos  @Apple will be adding more carrier support to ...
# 2   Pos  Hilarious @youtube video - guy does a duet wit...
# 3   Pos  @RIM you made it too easy for me to switch to ...
# 4   Pos  I just realized that the reason I got into twi...

# %% [markdown]
# ### WebScrapping: páginas web

# %%
import requests # get, post , put, delete, update
from bs4 import BeautifulSoup 
import re

# %%
pagina = requests.get("https://www.yelp.com/biz/la-casa-de-to%C3%B1o-ciudad-de-m%C3%A9xico-4")

# %%
pagina.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script async src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"><style data-emotion-css="0 xl0fej quqnuc 1n9j64s 4ut3yi 110vchp tza3mu 1enow5j 1jp7iek 1r5qcd8 cfcjyn 8dlaw4 xlzvdl 2sacua qgunke 1sb02f4 1sie4w0 kma813 15j7fnr war30n 79elbk 1t0p8qh 1suk6u5 1evauet e0tek0 ije6j5 ralh0w wonnhn 1fygppl 1udg11w 1fkqezt 1pz4y59 ux5mu6 1m051bw 1nrzw89 1fnccdf chan6m 9hjhab inq9gi 1c2abjj 12i50in 1rep3su tnmzvl 6a0jil 1oibaro u6xi54 1afdtvl 1nx1n9o 3u4ty 1lr1m88 uw1jq5 1pq36ol t8v44s 1lhjafl kjymuc 1qc6e87 foyide 1lx34my 144i0wq 1kq79li 1rjq8gp 16agjqd 1uk2nuw 19cdu5a 133wuwu 1gquror 12anxc3 1kuwv4w 4zp531 jcl426 1h0y4i5 abhuwp nyjpex 1hyrt2g na3oda 1nxvihb mdpdi2 11amnv8 9ba9vh fsp4s8 1emnyly 1g53q76 1vwj8bo 1rj15sq h19vjk 1m2gifa dh50jt yyr98k 4mfze4 1jac6c2 cv1jz2 fksa8h 147xtl9 19sk4h4 gutk1c dyjx0f 1fdy0l5 1ir4e44 11z402d 14b8va1 15hxdct 1w8jvj 1fliqpp r9996t 1um3nx 1p9ibgf cktstf 1t7f977 106vfgv xxqqxs qyp8bo 1wayfxy 1p80smk xp8w2v 1vhakgw qi10u5 qr9z5e 1lnf5f9">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:599px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:1023px){.responsive .responsive-medium-display-inline-block{display:inline-block !important;}.responsive .responsive-medium-display-block{display:block !important;}.responsive .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-medium-display-block{display:block !important;}.responsive-biz .responsive-medium-display-inline{display:inline !important;}}@ ...

# %%
osoup = BeautifulSoup(pagina.text, 'html.parser')

# %%
patron = re.compile('.*comment.*')

# %%
html_elements = osoup.find_all('p', {'class':patron})

# %%
html_elements
# Out:
# [<p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">Amazing food and well priced. It is definitely worth a visit. The waiters were friendly and the service fast.</span></p>,
#  <p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">Another amazing breakfast in Mexico City!<br/><br/>The chilaquiles were insanely good. <br/>I also had a fresh juice that was delicious.<br/><br/>Came here after a busy morning and got a late breakfast. There was a huge group of us, and the way they decided to take the orders/split the bills was a little confusing. Ultimately checking out went fine. <br/><br/>This place is always busy, because they are serving really delicious food at affordable prices in a casual and comfortable atmosphere.</span></p>,
#  <p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">Came here for the pozole as this is what this spot is known for and me and my other native friend loved the POZOLE DE POLLO. The flavors weren't overwhelming and it was light and non-greasy.  Paired with lemon and a side of guac, the small one was perfect for a medium brunch. My friend also tried their michelada tomatoño and he liked it too - it was a large mug. <br/><br/>Guacamole was pretty good too!<br/><br/>When we arrived on a weekday around 1:30p there was a line outside with 6 parties ahead of us, but we got seated within 15 mins after we took a number in line.  Upon entering they squirt some hands sanitizer on your hands. <br/><br/>Single Restrooms for men and women downstairs were pretty clean and had to struggle a bit for their soap but otherwise, the prices were a good deal for a tasty meal.</span></p>,
#  <p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">Great place if you want to eat cheap and delicious:) <br/><br/>I Always order the pozole without meat and two quesadillas de Chicharras</span></p>,
#  <p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">Amazing Pozole at an awesome price! I also enjoyed my horchata and tostada as well. Servers were nice and very efficient.</span></p>,
#  <p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">This place has amazing customer service.   The food was good but I was surprised it was so popular based on the food.   The guacamole was a standout of all of the things we had</span></p>,
#  <p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">I tried all of the highly recommended pozole spots based on google reviews. However, I was never impressed.<br/><br/>At one point I was convinced that I just simply didn't like pozole. That was until I gave in and went to la casa de tono.<br/><br/>I avoided this place for awhile because in my head chain food spots never really taste that good. Yet I'm glad I gave in! The dinning situation is very simple and straight forward. At first I was nervous because it was a lot of people so I figured service would be slowly. To my surprised they were fast and efficient. The pozole was so cheap too! <br/><br/>I left happy and full and I would definitely go back and patronize them again. So mark my words, the best pozole is at a casa de tono hands down.</span></p>,
#  <p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">This restaurant had the best Pozole I have ever had and it was like $4 US dollars. It's really a must have. Everyone enjoyed their meals.</span></p>,
#  <p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">After looking at the inside I recall how delicious this restaurant was and how I spilled my food down the front of my shirt and onto my lap. LOL Sure had some funny looks waiting to use the restroom to clean up and I all I could do was laugh!<br/><br/>Great customer service, freshly prepared Mexican fare and it was impressive!<br/><br/>Sadly my photos are gone with the wind.....</span></p>,
#  <p class="comment__09f24__gu0rG css-qgunke"><span class=" raw__09f24__T4Ezm" lang="en">Of all the local dining experiences in CDMX, this has been the best. Authentic food, fresh flavors and a busy, grab and go atmosphere seems like an impossible combination, but casa de toño was exactly what we needed after a long day of exploring.<br/><br/>I went to this restaurant three years ago and still think about the food, and had to write a review! We tried the Michelada, and enchiladas. My husband had the chicken enchiladas and we truly cannot stop dreaming of the food. We will be back one day!!</span></p>]

# %%
reviews_ct = [tag_texto.text for tag_texto in html_elements]

# %%
reviews_ct
# Out:
# ['Amazing food and well priced. It is definitely worth a visit. The waiters were friendly and the service fast.',
#  'Another amazing breakfast in Mexico City!The chilaquiles were insanely good. I also had a fresh juice that was delicious.Came here after a busy morning and got a late breakfast. There was a huge group of us, and the way they decided to take the orders/split the bills was a little confusing. Ultimately checking out went fine. This place is always busy, because they are serving really delicious food at affordable prices in a casual and comfortable atmosphere.',
#  "Came here for the pozole as this is what this spot is known for and me and my other native friend loved the POZOLE DE POLLO. The flavors weren't overwhelming and it was light and non-greasy. \xa0Paired with lemon and a side of guac, the small one was perfect for a medium brunch. My friend also tried their michelada tomatoño and he liked it too - it was a large mug. Guacamole was pretty good too!When we arrived on a weekday around 1:30p there was a line outside with 6 parties ahead of us, but we got seated within 15 mins after we took a number in line. \xa0Upon entering they squirt some hands sanitizer on your hands. Single Restrooms for men and women downstairs were pretty clean and had to struggle a bit for their soap but otherwise, the prices were a good deal for a tasty meal.",
#  'Great place if you want to eat cheap and delicious:) I Always order the pozole without meat and two quesadillas de Chicharras',
#  'Amazing Pozole at an awesome price! I also enjoyed my horchata and tostada as well. Servers were nice and very efficient.',
#  'This place has amazing customer service. \xa0 The food was good but I was surprised it was so popular based on the food. \xa0 The guacamole was a standout of all of the things we had',
#  "I tried all of the highly recommended pozole spots based on google reviews. However, I was never impressed.At one point I was convinced that I just simply didn't like pozole. That was until I gave in and went to la casa de tono.I avoided this place for awhile because in my head chain food spots never really taste that good. Yet I'm glad I gave in! The dinning situation is very simple and straight forward. At first I was nervous because it was a lot of people so I figured service would be slowly. To my surprised they were fast and efficient. The pozole was so cheap too! I left happy and full and I would definitely go back and patronize them again. So mark my words, the best pozole is at a casa de tono hands down.",
#  "This restaurant had the best Pozole I have ever had and it was like $4 US dollars. It's really a must have. Everyone enjoyed their meals.",
#  'After looking at the inside I recall how delicious this restaurant was and how I spilled my food down the front of my shirt and onto my lap. LOL Sure had some funny looks waiting to use the restroom to clean up and I all I could do was laugh!Great customer service, freshly prepared Mexican fare and it was impressive!Sadly my photos are gone with the wind.....',
#  'Of all the local dining experiences in CDMX, this has been the best. Authentic food, fresh flavors and a busy, grab and go atmosphere seems like an impossible combination, but casa de toño was exactly what we needed after a long day of exploring.I went to this restaurant three years ago and still think about the food, and had to write a review! We tried the Michelada, and enchiladas. My husband had the chicken enchiladas and we truly cannot stop dreaming of the food. We will be back one day!!']

# %% [markdown]
# # Word2Vec
# ## Word2vec es una técnica para el procesamiento del lenguaje natural publicada en 2013. El algoritmo word2vec utiliza un modelo de red neuronal para aprender asociaciones de palabras de un gran corpus de texto. Una vez entrenado, dicho modelo puede detectar palabras sinónimas o sugerir palabras adicionales para una oración parcial. Como su nombre lo indica, word2vec representa cada palabra distinta con una lista particular de números llamada vector.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # “i like _____ language processing”

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from gensim.models import word2vec

# %%
corpus.head()
# Out:
#                                              reviews  \
# 0  El cine asitico se ha convertido ya en lo que ...
# 1  Es curioso observar cmo hasta el propio cine s...
# 2  Es que no la cagan en ninguna, todas las pelis...
# 3  "Los 100 golpes", as se llama el polmico y exi...
# 4  Una Historia Violenta, 2005, es verdaderamente...
#
#                                               tokens
# 0  [cine, asitico, convertido, conjunto, pases, o...
# 1  [curioso, observar, cmo, propio, cine, debate,...
# 2  [cagan, ninguna, todas, pelis, hacen, cada, ve...
# 3  [golpes, as, llama, polmico, exitoso, libro, a...
# 4  [historia, violenta, verdaderamente, violenta,...

# %%
modelow2v = word2vec.Word2Vec(corpus.tokens.to_list())

# %%
print(modelow2v)
# Out:
# Word2Vec(vocab=879, size=100, alpha=0.025)

# %%
modelow2v.wv.vocab
# Out:
# {'absolutamente': <gensim.models.keyedvectors.Vocab at 0x7f58076c6dd0>,
#  'absoluto': <gensim.models.keyedvectors.Vocab at 0x7f58096e4f50>,
#  'aburrida': <gensim.models.keyedvectors.Vocab at 0x7f58096d6090>,
#  'acaba': <gensim.models.keyedvectors.Vocab at 0x7f5809702a10>,
#  'academia': <gensim.models.keyedvectors.Vocab at 0x7f58076a5210>,
#  'accin': <gensim.models.keyedvectors.Vocab at 0x7f58096d6510>,
#  'acciones': <gensim.models.keyedvectors.Vocab at 0x7f58076a3310>,
#  'acerca': <gensim.models.keyedvectors.Vocab at 0x7f58076a5050>,
#  'acompaa': <gensim.models.keyedvectors.Vocab at 0x7f58076a5ed0>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7f58076a5850>,
#  'actores': <gensim.models.keyedvectors.Vocab at 0x7f58096e16d0>,
#  'actos': <gensim.models.keyedvectors.Vocab at 0x7f58096ead10>,
#  'actriz': <gensim.models.keyedvectors.Vocab at 0x7f5809705150>,
#  'actuacin': <gensim.models.keyedvectors.Vocab at 0x7f58096e1650>,
#  'actuaciones': <gensim.models.keyedvectors.Vocab at 0x7f58096e15d0>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x7f5809705310>,
#  'adaptacin': <gensim.models.keyedvectors.Vocab at 0x7f58076aa350>,
#  'adems': <gensim.models.keyedvectors.Vocab at 0x7f58076aa210>,
#  'adolescente': <gensim.models.keyedvectors.Vocab at 0x7f58096e4a10>,
#  'ah': <gensim.models.keyedvectors.Vocab at 0x7f58097bb310>,
#  'ahora': <gensim.models.keyedvectors.Vocab at 0x7f5809709fd0>,
#  'aire': <gensim.models.keyedvectors.Vocab at 0x7f5809709f10>,
#  'algn': <gensim.models.keyedvectors.Vocab at 0x7f5809702610>,
#  'alguien': <gensim.models.keyedvectors.Vocab at 0x7f5809709f50>,
#  'alguna': <gensim.models.keyedvectors.Vocab at 0x7f58097bb3d0>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f580970a4d0>,
#  'alma': <gensim.models.keyedvectors.Vocab at 0x7f58076a1110>,
#  'alrededor': <gensim.models.keyedvectors.Vocab at 0x7f5809702c10>,
#  'alto': <gensim.models.keyedvectors.Vocab at 0x7f5809705f10>,
#  'ambientacin': <gensim.models.keyedvectors.Vocab at 0x7f58096e2fd0>,
#  'ambiente': <gensim.models.keyedvectors.Vocab at 0x7f58096f3cd0>,
#  'ambos': <gensim.models.keyedvectors.Vocab at 0x7f580970a650>,
#  'americana': <gensim.models.keyedvectors.Vocab at 0x7f58076a1350>,
#  'americano': <gensim.models.keyedvectors.Vocab at 0x7f58096d6150>,
#  'amigo': <gensim.models.keyedvectors.Vocab at 0x7f58096f3f50>,
#  'amigos': <gensim.models.keyedvectors.Vocab at 0x7f58076a1210>,
#  'amor': <gensim.models.keyedvectors.Vocab at 0x7f5809721a10>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f58096e1bd0>,
#  'ang': <gensim.models.keyedvectors.Vocab at 0x7f58096e2b50>,
#  'anterior': <gensim.models.keyedvectors.Vocab at 0x7f58096e23d0>,
#  'anteriores': <gensim.models.keyedvectors.Vocab at 0x7f58096f3b10>,
#  'anteriormente': <gensim.models.keyedvectors.Vocab at 0x7f5809739550>,
#  'ao': <gensim.models.keyedvectors.Vocab at 0x7f58096e1510>,
#  'aos': <gensim.models.keyedvectors.Vocab at 0x7f5809721950>,
#  'aparece': <gensim.models.keyedvectors.Vocab at 0x7f58096e1b10>,
#  'aparentemente': <gensim.models.keyedvectors.Vocab at 0x7f58076a5d10>,
#  'aparte': <gensim.models.keyedvectors.Vocab at 0x7f580974cfd0>,
#  'apenas': <gensim.models.keyedvectors.Vocab at 0x7f5809705050>,
#  'aqu': <gensim.models.keyedvectors.Vocab at 0x7f580970ad10>,
#  'aquel': <gensim.models.keyedvectors.Vocab at 0x7f58096e2290>,
#  'aquella': <gensim.models.keyedvectors.Vocab at 0x7f5809705110>,
#  'aquello': <gensim.models.keyedvectors.Vocab at 0x7f58076a3350>,
#  'aquellos': <gensim.models.keyedvectors.Vocab at 0x7f58096f3e50>,
#  'argumento': <gensim.models.keyedvectors.Vocab at 0x7f58096f3d90>,
#  'arte': <gensim.models.keyedvectors.Vocab at 0x7f58096f3910>,
#  'artista': <gensim.models.keyedvectors.Vocab at 0x7f58076a3550>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f580970a3d0>,
#  'asesino': <gensim.models.keyedvectors.Vocab at 0x7f58096f3150>,
#  'asesinos': <gensim.models.keyedvectors.Vocab at 0x7f58097058d0>,
#  'asi': <gensim.models.keyedvectors.Vocab at 0x7f5809705c50>,
#  'aspecto': <gensim.models.keyedvectors.Vocab at 0x7f58096e4d90>,
#  'aspectos': <gensim.models.keyedvectors.Vocab at 0x7f58096e2410>,
#  'atencin': <gensim.models.keyedvectors.Vocab at 0x7f58096e4310>,
#  'atrs': <gensim.models.keyedvectors.Vocab at 0x7f58096d6190>,
#  'aun': <gensim.models.keyedvectors.Vocab at 0x7f58096e4b90>,
#  'aunque': <gensim.models.keyedvectors.Vocab at 0x7f58096e1410>,
#  'ayer': <gensim.models.keyedvectors.Vocab at 0x7f58096e4650>,
#  'ayuda': <gensim.models.keyedvectors.Vocab at 0x7f5809702e10>,
#  'bajo': <gensim.models.keyedvectors.Vocab at 0x7f58096e4990>,
#  'banda': <gensim.models.keyedvectors.Vocab at 0x7f58096ea890>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7f5809739dd0>,
#  'bastante': <gensim.models.keyedvectors.Vocab at 0x7f58096d6f50>,
#  'batalla': <gensim.models.keyedvectors.Vocab at 0x7f58076a5650>,
#  'belleza': <gensim.models.keyedvectors.Vocab at 0x7f58076a11d0>,
#  'bergman': <gensim.models.keyedvectors.Vocab at 0x7f58076a3690>,
#  'bichos': <gensim.models.keyedvectors.Vocab at 0x7f58096e4790>,
#  'bien': <gensim.models.keyedvectors.Vocab at 0x7f58097028d0>,
#  'blanco': <gensim.models.keyedvectors.Vocab at 0x7f58096e17d0>,
#  'boca': <gensim.models.keyedvectors.Vocab at 0x7f58076a1b50>,
#  'bree': <gensim.models.keyedvectors.Vocab at 0x7f58076a3610>,
#  'brokeback': <gensim.models.keyedvectors.Vocab at 0x7f58097098d0>,
#  'bsqueda': <gensim.models.keyedvectors.Vocab at 0x7f58096e4750>,
#  'buen': <gensim.models.keyedvectors.Vocab at 0x7f58096d6550>,
#  'buena': <gensim.models.keyedvectors.Vocab at 0x7f58096e1690>,
#  'buenas': <gensim.models.keyedvectors.Vocab at 0x7f5809705710>,
#  'bueno': <gensim.models.keyedvectors.Vocab at 0x7f5809705ed0>,
#  'buenos': <gensim.models.keyedvectors.Vocab at 0x7f5809705810>,
#  'buscando': <gensim.models.keyedvectors.Vocab at 0x7f58076a3250>,
#  'buscar': <gensim.models.keyedvectors.Vocab at 0x7f580970a850>,
#  'cabeza': <gensim.models.keyedvectors.Vocab at 0x7f58096f3490>,
#  'cabo': <gensim.models.keyedvectors.Vocab at 0x7f5809702650>,
#  'cach': <gensim.models.keyedvectors.Vocab at 0x7f58076a5cd0>,
#  'cada': <gensim.models.keyedvectors.Vocab at 0x7f5809709b10>,
#  'cadena': <gensim.models.keyedvectors.Vocab at 0x7f58076a1710>,
#  'cae': <gensim.models.keyedvectors.Vocab at 0x7f58076a1d10>,
#  'caer': <gensim.models.keyedvectors.Vocab at 0x7f5809709c10>,
#  'calidad': <gensim.models.keyedvectors.Vocab at 0x7f58076c6c10>,
#  'cambia': <gensim.models.keyedvectors.Vocab at 0x7f580970ae10>,
#  'cambio': <gensim.models.keyedvectors.Vocab at 0x7f5809709850>,
#  'camino': <gensim.models.keyedvectors.Vocab at 0x7f5809739e50>,
#  'capaz': <gensim.models.keyedvectors.Vocab at 0x7f58096e2dd0>,
#  'capote': <gensim.models.keyedvectors.Vocab at 0x7f58076a1e90>,
#  'cara': <gensim.models.keyedvectors.Vocab at 0x7f58096e4250>,
#  'carcter': <gensim.models.keyedvectors.Vocab at 0x7f58096f37d0>,
#  'carne': <gensim.models.keyedvectors.Vocab at 0x7f58096f3b90>,
#  'carpenter': <gensim.models.keyedvectors.Vocab at 0x7f58096e2090>,
#  'carrera': <gensim.models.keyedvectors.Vocab at 0x7f58096e2d50>,
#  'casa': <gensim.models.keyedvectors.Vocab at 0x7f580970ae90>,
#  'casanova': <gensim.models.keyedvectors.Vocab at 0x7f58076a5950>,
#  'cash': <gensim.models.keyedvectors.Vocab at 0x7f58076a1250>,
#  'casi': <gensim.models.keyedvectors.Vocab at 0x7f5809721750>,
#  'caso': <gensim.models.keyedvectors.Vocab at 0x7f5809709150>,
#  'casos': <gensim.models.keyedvectors.Vocab at 0x7f58076a16d0>,
#  'cera': <gensim.models.keyedvectors.Vocab at 0x7f58076a1d90>,
#  'cerca': <gensim.models.keyedvectors.Vocab at 0x7f58076c6a90>,
#  'cercano': <gensim.models.keyedvectors.Vocab at 0x7f58096f34d0>,
#  'chaval': <gensim.models.keyedvectors.Vocab at 0x7f58096ea6d0>,
#  'chica': <gensim.models.keyedvectors.Vocab at 0x7f5809705410>,
#  'chico': <gensim.models.keyedvectors.Vocab at 0x7f58076a34d0>,
#  'cierta': <gensim.models.keyedvectors.Vocab at 0x7f58096d6110>,
#  'cierto': <gensim.models.keyedvectors.Vocab at 0x7f58076aa150>,
#  'ciertos': <gensim.models.keyedvectors.Vocab at 0x7f5809709290>,
#  'cinco': <gensim.models.keyedvectors.Vocab at 0x7f5809721510>,
#  'cine': <gensim.models.keyedvectors.Vocab at 0x7f58076aa390>,
#  'cineasta': <gensim.models.keyedvectors.Vocab at 0x7f58076a33d0>,
#  'cinematogrfica': <gensim.models.keyedvectors.Vocab at 0x7f58076c6890>,
#  'cinematogrfico': <gensim.models.keyedvectors.Vocab at 0x7f5809739750>,
#  'cinta': <gensim.models.keyedvectors.Vocab at 0x7f5809702b50>,
#  'cintas': <gensim.models.keyedvectors.Vocab at 0x7f58076a5410>,
#  'ciudad': <gensim.models.keyedvectors.Vocab at 0x7f58096eaa90>,
#  'claramente': <gensim.models.keyedvectors.Vocab at 0x7f58096ea490>,
#  'claro': <gensim.models.keyedvectors.Vocab at 0x7f580970a6d0>,
#  'clase': <gensim.models.keyedvectors.Vocab at 0x7f58096f3650>,
#  'clooney': <gensim.models.keyedvectors.Vocab at 0x7f58096e1750>,
#  'clsico': <gensim.models.keyedvectors.Vocab at 0x7f58096e1890>,
#  'cmara': <gensim.models.keyedvectors.Vocab at 0x7f58096e1950>,
#  'cmo': <gensim.models.keyedvectors.Vocab at 0x7f5809702f90>,
#  'comedia': <gensim.models.keyedvectors.Vocab at 0x7f58076a58d0>,
#  'comienza': <gensim.models.keyedvectors.Vocab at 0x7f58096ea290>,
#  'comienzo': <gensim.models.keyedvectors.Vocab at 0x7f5809705d90>,
#  'complicado': <gensim.models.keyedvectors.Vocab at 0x7f580970a290>,
#  'comprender': <gensim.models.keyedvectors.Vocab at 0x7f5809709510>,
#  'conciencia': <gensim.models.keyedvectors.Vocab at 0x7f58076a5c50>,
#  'condicin': <gensim.models.keyedvectors.Vocab at 0x7f580970acd0>,
#  'confesiones': <gensim.models.keyedvectors.Vocab at 0x7f58076a5710>,
#  'conflictos': <gensim.models.keyedvectors.Vocab at 0x7f58096d6990>,
#  'conocer': <gensim.models.keyedvectors.Vocab at 0x7f5809705090>,
#  'conocido': <gensim.models.keyedvectors.Vocab at 0x7f5809721e50>,
#  'consecuencias': <gensim.models.keyedvectors.Vocab at 0x7f58096e1390>,
#  'conseguir': <gensim.models.keyedvectors.Vocab at 0x7f58076a5290>,
#  'consigue': <gensim.models.keyedvectors.Vocab at 0x7f58096d6590>,
#  'constante': <gensim.models.keyedvectors.Vocab at 0x7f58096f3c50>,
#  'contar': <gensim.models.keyedvectors.Vocab at 0x7f58096e1310>,
#  'contenido': <gensim.models.keyedvectors.Vocab at 0x7f58096eaad0>,
#  'convence': <gensim.models.keyedvectors.Vocab at 0x7f58096e1190>,
#  'convertido': <gensim.models.keyedvectors.Vocab at 0x7f58076aa310>,
#  'convertir': <gensim.models.keyedvectors.Vocab at 0x7f580970a710>,
#  'convierte': <gensim.models.keyedvectors.Vocab at 0x7f58096e2310>,
#  'corazn': <gensim.models.keyedvectors.Vocab at 0x7f58076a3510>,
#  'correcta': <gensim.models.keyedvectors.Vocab at 0x7f5809709490>,
#  'cosa': <gensim.models.keyedvectors.Vocab at 0x7f58076c6610>,
#  'cosas': <gensim.models.keyedvectors.Vocab at 0x7f580970afd0>,
#  'crash': <gensim.models.keyedvectors.Vocab at 0x7f58096d6750>,
#  'crea': <gensim.models.keyedvectors.Vocab at 0x7f58096ea050>,
#  'creble': <gensim.models.keyedvectors.Vocab at 0x7f58076a10d0>,
#  'creo': <gensim.models.keyedvectors.Vocab at 0x7f5809721190>,
#  'crimen': <gensim.models.keyedvectors.Vocab at 0x7f58096d6b10>,
#  'crtica': <gensim.models.keyedvectors.Vocab at 0x7f58096e2610>,
#  'crticas': <gensim.models.keyedvectors.Vocab at 0x7f580970af90>,
#  'cruda': <gensim.models.keyedvectors.Vocab at 0x7f58076a1910>,
#  'cruel': <gensim.models.keyedvectors.Vocab at 0x7f58096ead90>,
#  'cualquier': <gensim.models.keyedvectors.Vocab at 0x7f580970ad90>,
#  'cuanto': <gensim.models.keyedvectors.Vocab at 0x7f58097024d0>,
#  'cuatro': <gensim.models.keyedvectors.Vocab at 0x7f58096e29d0>,
#  'cuenta': <gensim.models.keyedvectors.Vocab at 0x7f58096e1990>,
#  'cuentan': <gensim.models.keyedvectors.Vocab at 0x7f58097057d0>,
#  'cuento': <gensim.models.keyedvectors.Vocab at 0x7f58097053d0>,
#  'cuerpo': <gensim.models.keyedvectors.Vocab at 0x7f58076a5a10>,
#  'cuestin': <gensim.models.keyedvectors.Vocab at 0x7f58096f32d0>,
#  'cuestiones': <gensim.models.keyedvectors.Vocab at 0x7f58096e4110>,
#  'culpa': <gensim.models.keyedvectors.Vocab at 0x7f58096f36d0>,
#  'curioso': <gensim.models.keyedvectors.Vocab at 0x7f5809863e10>,
#  'curritos': <gensim.models.keyedvectors.Vocab at 0x7f58096ea750>,
#  'cuya': <gensim.models.keyedvectors.Vocab at 0x7f58096d6350>,
#  'da': <gensim.models.keyedvectors.Vocab at 0x7f58076c6650>,
#  'dado': <gensim.models.keyedvectors.Vocab at 0x7f5809702790>,
#  'dan': <gensim.models.keyedvectors.Vocab at 0x7f580970a610>,
#  'dar': <gensim.models.keyedvectors.Vocab at 0x7f58097050d0>,
#  'darle': <gensim.models.keyedvectors.Vocab at 0x7f5809705bd0>,
#  'das': <gensim.models.keyedvectors.Vocab at 0x7f58096e4590>,
#  'david': <gensim.models.keyedvectors.Vocab at 0x7f58096e1a90>,
#  'dcada': <gensim.models.keyedvectors.Vocab at 0x7f58076a1990>,
#  'debe': <gensim.models.keyedvectors.Vocab at 0x7f58096eae90>,
#  'debera': <gensim.models.keyedvectors.Vocab at 0x7f58096e46d0>,
#  'debido': <gensim.models.keyedvectors.Vocab at 0x7f58096e4e90>,
#  'deca': <gensim.models.keyedvectors.Vocab at 0x7f580970a210>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7f58096f3bd0>,
#  'decir': <gensim.models.keyedvectors.Vocab at 0x7f580974cdd0>,
#  'decisin': <gensim.models.keyedvectors.Vocab at 0x7f58096f3850>,
#  'definitiva': <gensim.models.keyedvectors.Vocab at 0x7f5809709310>,
#  'deja': <gensim.models.keyedvectors.Vocab at 0x7f58076a5110>,
#  'dejado': <gensim.models.keyedvectors.Vocab at 0x7f5809705290>,
#  'dejan': <gensim.models.keyedvectors.Vocab at 0x7f5809705910>,
#  'dejar': <gensim.models.keyedvectors.Vocab at 0x7f5809702b10>,
#  'delante': <gensim.models.keyedvectors.Vocab at 0x7f58076a31d0>,
#  'demasiado': <gensim.models.keyedvectors.Vocab at 0x7f58096e4e10>,
#  'dems': <gensim.models.keyedvectors.Vocab at 0x7f58076a5f90>,
#  'demuestra': <gensim.models.keyedvectors.Vocab at 0x7f58096e2e10>,
#  'den': <gensim.models.keyedvectors.Vocab at 0x7f58096e2b10>,
#  'dentro': <gensim.models.keyedvectors.Vocab at 0x7f58096d6c50>,
#  'desarrolla': <gensim.models.keyedvectors.Vocab at 0x7f58096ea450>,
#  'desarrollo': <gensim.models.keyedvectors.Vocab at 0x7f5809702690>,
#  'descubrir': <gensim.models.keyedvectors.Vocab at 0x7f580970a510>,
#  'despus': <gensim.models.keyedvectors.Vocab at 0x7f58096e1d90>,
#  'destaca': <gensim.models.keyedvectors.Vocab at 0x7f58096e4cd0>,
#  'destacar': <gensim.models.keyedvectors.Vocab at 0x7f5809739450>,
#  'destino': <gensim.models.keyedvectors.Vocab at 0x7f58076a5790>,
#  'detalle': <gensim.models.keyedvectors.Vocab at 0x7f58096e4c50>,
#  'detalles': <gensim.models.keyedvectors.Vocab at 0x7f58076a1e50>,
#  'dice': <gensim.models.keyedvectors.Vocab at 0x7f58076c67d0>,
#  'dicen': <gensim.models.keyedvectors.Vocab at 0x7f58076a32d0>,
#  'dicha': <gensim.models.keyedvectors.Vocab at 0x7f58096e4f90>,
#  'dicho': <gensim.models.keyedvectors.Vocab at 0x7f5809705450>,
#  'difcil': <gensim.models.keyedvectors.Vocab at 0x7f58096f3690>,
#  'diferencia': <gensim.models.keyedvectors.Vocab at 0x7f58096d6290>,
#  'diferente': <gensim.models.keyedvectors.Vocab at 0x7f58096d6710>,
#  'diferentes': <gensim.models.keyedvectors.Vocab at 0x7f58076c6750>,
#  'digo': <gensim.models.keyedvectors.Vocab at 0x7f58076a14d0>,
#  'dilogos': <gensim.models.keyedvectors.Vocab at 0x7f58096ea550>,
#  'dio': <gensim.models.keyedvectors.Vocab at 0x7f580970ac90>,
#  'dios': <gensim.models.keyedvectors.Vocab at 0x7f58096e1e90>,
#  'direccin': <gensim.models.keyedvectors.Vocab at 0x7f58097211d0>,
#  'directamente': <gensim.models.keyedvectors.Vocab at 0x7f58096eabd0>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x7f58076aa190>,
#  'dirigida': <gensim.models.keyedvectors.Vocab at 0x7f58096ea250>,
#  'dolor': <gensim.models.keyedvectors.Vocab at 0x7f58076a1a90>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x7f58096d6e50>,
#  'dos': <gensim.models.keyedvectors.Vocab at 0x7f58076aa450>,
#  'dosis': <gensim.models.keyedvectors.Vocab at 0x7f58096e4090>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x7f58076c6e90>,
#  'duda': <gensim.models.keyedvectors.Vocab at 0x7f58096e1e50>,
#  'duro': <gensim.models.keyedvectors.Vocab at 0x7f58076a1c10>,
#  'efectos': <gensim.models.keyedvectors.Vocab at 0x7f58096e2810>,
#  'egosmo': <gensim.models.keyedvectors.Vocab at 0x7f58076a3790>,
#  'ejemplo': <gensim.models.keyedvectors.Vocab at 0x7f58096e2f50>,
#  'elementos': <gensim.models.keyedvectors.Vocab at 0x7f58076c6ed0>,
#  'elenco': <gensim.models.keyedvectors.Vocab at 0x7f58096e1710>,
#  'ello': <gensim.models.keyedvectors.Vocab at 0x7f580970af50>,
#  'embargo': <gensim.models.keyedvectors.Vocab at 0x7f58096e2190>,
#  'emocional': <gensim.models.keyedvectors.Vocab at 0x7f58096f3750>,
#  'empezar': <gensim.models.keyedvectors.Vocab at 0x7f58096e4ad0>,
#  'empieza': <gensim.models.keyedvectors.Vocab at 0x7f58096e2390>,
#  'encima': <gensim.models.keyedvectors.Vocab at 0x7f58096d61d0>,
#  'encontrado': <gensim.models.keyedvectors.Vocab at 0x7f58076a1590>,
#  'encontramos': <gensim.models.keyedvectors.Vocab at 0x7f58096f3dd0>,
#  'encuentra': <gensim.models.keyedvectors.Vocab at 0x7f58096e4a50>,
#  'encuentran': <gensim.models.keyedvectors.Vocab at 0x7f58096ea410>,
#  'encuentro': <gensim.models.keyedvectors.Vocab at 0x7f580970a890>,
#  'encuentros': <gensim.models.keyedvectors.Vocab at 0x7f58096e42d0>,
#  'enemigo': <gensim.models.keyedvectors.Vocab at 0x7f58096e2710>,
#  'engancha': <gensim.models.keyedvectors.Vocab at 0x7f58096ea910>,
#  'ennis': <gensim.models.keyedvectors.Vocab at 0x7f58096f3d10>,
#  'entiende': <gensim.models.keyedvectors.Vocab at 0x7f5809702d90>,
#  'entonces': <gensim.models.keyedvectors.Vocab at 0x7f58076a1e10>,
#  'entorno': <gensim.models.keyedvectors.Vocab at 0x7f580970abd0>,
#  'entra': <gensim.models.keyedvectors.Vocab at 0x7f58096ea710>,
#  'entretenida': <gensim.models.keyedvectors.Vocab at 0x7f58096e2550>,
#  'eric': <gensim.models.keyedvectors.Vocab at 0x7f58096ea2d0>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x7f58076a3590>,
#  'escena': <gensim.models.keyedvectors.Vocab at 0x7f58096e19d0>,
#  'escenas': <gensim.models.keyedvectors.Vocab at 0x7f58096e1250>,
#  'escribir': <gensim.models.keyedvectors.Vocab at 0x7f5809721610>,
#  'escrito': <gensim.models.keyedvectors.Vocab at 0x7f58096d6890>,
#  'escritor': <gensim.models.keyedvectors.Vocab at 0x7f58096ea9d0>,
#  'esencia': <gensim.models.keyedvectors.Vocab at 0x7f580970a8d0>,
#  'esfuerzo': <gensim.models.keyedvectors.Vocab at 0x7f58096e4e50>,
#  'especial': <gensim.models.keyedvectors.Vocab at 0x7f58096e2590>,
#  'especiales': <gensim.models.keyedvectors.Vocab at 0x7f58096e4850>,
#  'especialmente': <gensim.models.keyedvectors.Vocab at 0x7f58096d6dd0>,
#  'especie': <gensim.models.keyedvectors.Vocab at 0x7f58076c6d90>,
#  'espectador': <gensim.models.keyedvectors.Vocab at 0x7f580970a950>,
#  'espectadores': <gensim.models.keyedvectors.Vocab at 0x7f58076a5c90>,
#  'espera': <gensim.models.keyedvectors.Vocab at 0x7f58096e24d0>,
#  'esperaba': <gensim.models.keyedvectors.Vocab at 0x7f58096e1e10>,
#  'esperando': <gensim.models.keyedvectors.Vocab at 0x7f58076a1390>,
#  'esperar': <gensim.models.keyedvectors.Vocab at 0x7f58096e1210>,
#  'esposa': <gensim.models.keyedvectors.Vocab at 0x7f58096e4290>,
#  'espritu': <gensim.models.keyedvectors.Vocab at 0x7f58096f3810>,
#  'est': <gensim.models.keyedvectors.Vocab at 0x7f580970a190>,
#  'estilo': <gensim.models.keyedvectors.Vocab at 0x7f58096e1850>,
#  'estn': <gensim.models.keyedvectors.Vocab at 0x7f58076c6b10>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7f58096e1590>,
#  'evidente': <gensim.models.keyedvectors.Vocab at 0x7f58076c6f10>,
#  'evitar': <gensim.models.keyedvectors.Vocab at 0x7f5809709990>,
#  'excelente': <gensim.models.keyedvectors.Vocab at 0x7f58096d6fd0>,
#  'existe': <gensim.models.keyedvectors.Vocab at 0x7f58096e25d0>,
#  'existencia': <gensim.models.keyedvectors.Vocab at 0x7f580970a550>,
#  'expectativas': <gensim.models.keyedvectors.Vocab at 0x7f58096e14d0>,
#  'extrao': <gensim.models.keyedvectors.Vocab at 0x7f58096eae10>,
#  'falta': <gensim.models.keyedvectors.Vocab at 0x7f58097095d0>,
#  'familia': <gensim.models.keyedvectors.Vocab at 0x7f58096f3ed0>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x7f58076c6e50>,
#  'familiares': <gensim.models.keyedvectors.Vocab at 0x7f58096ea850>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x7f580970a310>,
#  'fcil': <gensim.models.keyedvectors.Vocab at 0x7f5809709bd0>,
#  'felicity': <gensim.models.keyedvectors.Vocab at 0x7f58097091d0>,
#  'fiel': <gensim.models.keyedvectors.Vocab at 0x7f58096e4d50>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7f58076c6990>,
#  'filme': <gensim.models.keyedvectors.Vocab at 0x7f58096f3c10>,
#  'filmografa': <gensim.models.keyedvectors.Vocab at 0x7f58096e2d90>,
#  'films': <gensim.models.keyedvectors.Vocab at 0x7f58096e4d10>,
#  'fin': <gensim.models.keyedvectors.Vocab at 0x7f5809705610>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x7f5809705d50>,
#  'forma': <gensim.models.keyedvectors.Vocab at 0x7f58096eac10>,
#  'formal': <gensim.models.keyedvectors.Vocab at 0x7f5809709410>,
#  'fotografa': <gensim.models.keyedvectors.Vocab at 0x7f58096e4610>,
#  'fra': <gensim.models.keyedvectors.Vocab at 0x7f58096e4dd0>,
#  'frase': <gensim.models.keyedvectors.Vocab at 0x7f5809705650>,
#  'frente': <gensim.models.keyedvectors.Vocab at 0x7f580970aad0>,
#  'fuerte': <gensim.models.keyedvectors.Vocab at 0x7f58096e1550>,
#  'fuerza': <gensim.models.keyedvectors.Vocab at 0x7f58096eaed0>,
#  'futuro': <gensim.models.keyedvectors.Vocab at 0x7f58096eab50>,
#  'genial': <gensim.models.keyedvectors.Vocab at 0x7f5809709250>,
#  'genio': <gensim.models.keyedvectors.Vocab at 0x7f58076a50d0>,
#  'gente': <gensim.models.keyedvectors.Vocab at 0x7f58076a1650>,
#  'george': <gensim.models.keyedvectors.Vocab at 0x7f58096f3990>,
#  'gnero': <gensim.models.keyedvectors.Vocab at 0x7f58096d64d0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f58076a30d0>,
#  'gracias': <gensim.models.keyedvectors.Vocab at 0x7f58076c6690>,
#  'grado': <gensim.models.keyedvectors.Vocab at 0x7f58096f3b50>,
#  'gran': <gensim.models.keyedvectors.Vocab at 0x7f58076aa2d0>,
#  'grandes': <gensim.models.keyedvectors.Vocab at 0x7f58096ea950>,
#  'grupo': <gensim.models.keyedvectors.Vocab at 0x7f58096ea190>,
#  'guerra': <gensim.models.keyedvectors.Vocab at 0x7f58096eadd0>,
#  'guin': <gensim.models.keyedvectors.Vocab at 0x7f58096e1a10>,
#  'guionista': <gensim.models.keyedvectors.Vocab at 0x7f58096d6610>,
#  'gust': <gensim.models.keyedvectors.Vocab at 0x7f58076a5150>,
#  'gusta': <gensim.models.keyedvectors.Vocab at 0x7f58076a1450>,
#  'gusto': <gensim.models.keyedvectors.Vocab at 0x7f5809721ad0>,
#  'gyllenhaal': <gensim.models.keyedvectors.Vocab at 0x7f58076a1090>,
#  'haba': <gensim.models.keyedvectors.Vocab at 0x7f58096e2150>,
#  'haber': <gensim.models.keyedvectors.Vocab at 0x7f58096d6850>,
#  'habitual': <gensim.models.keyedvectors.Vocab at 0x7f58076a5f50>,
#  'habla': <gensim.models.keyedvectors.Vocab at 0x7f580970a250>,
#  'hablando': <gensim.models.keyedvectors.Vocab at 0x7f58076c65d0>,
#  'hablar': <gensim.models.keyedvectors.Vocab at 0x7f58096e2650>,
#  'haca': <gensim.models.keyedvectors.Vocab at 0x7f58076a1810>,
#  'hace': <gensim.models.keyedvectors.Vocab at 0x7f580970a910>,
#  'hacen': <gensim.models.keyedvectors.Vocab at 0x7f58097096d0>,
#  'hacer': <gensim.models.keyedvectors.Vocab at 0x7f5809709c90>,
#  'hacia': <gensim.models.keyedvectors.Vocab at 0x7f58096eae50>,
#  'haciendo': <gensim.models.keyedvectors.Vocab at 0x7f5809709110>,
#  'haga': <gensim.models.keyedvectors.Vocab at 0x7f580970a110>,
#  'haggis': <gensim.models.keyedvectors.Vocab at 0x7f58096d67d0>,
#  'haneke': <gensim.models.keyedvectors.Vocab at 0x7f58076a5c10>,
#  'harry': <gensim.models.keyedvectors.Vocab at 0x7f58096ea7d0>,
#  'heath': <gensim.models.keyedvectors.Vocab at 0x7f58076a1050>,
#  'hecho': <gensim.models.keyedvectors.Vocab at 0x7f58076aa0d0>,
#  'hechos': <gensim.models.keyedvectors.Vocab at 0x7f58076a18d0>,
#  'hermana': <gensim.models.keyedvectors.Vocab at 0x7f58096e49d0>,
#  'hermano': <gensim.models.keyedvectors.Vocab at 0x7f58096e4a90>,
#  'hermanos': <gensim.models.keyedvectors.Vocab at 0x7f58096d6ad0>,
#  'hija': <gensim.models.keyedvectors.Vocab at 0x7f5809702cd0>,
#  'hijo': <gensim.models.keyedvectors.Vocab at 0x7f580970a590>,
#  'historia': <gensim.models.keyedvectors.Vocab at 0x7f5809721d90>,
#  'historias': <gensim.models.keyedvectors.Vocab at 0x7f58096d6b90>,
#  'hizo': <gensim.models.keyedvectors.Vocab at 0x7f58096e4710>,
#  'hoffman': <gensim.models.keyedvectors.Vocab at 0x7f58076a1fd0>,
#  'hollywood': <gensim.models.keyedvectors.Vocab at 0x7f58096e18d0>,
#  'hombre': <gensim.models.keyedvectors.Vocab at 0x7f58096e4690>,
#  'hombres': <gensim.models.keyedvectors.Vocab at 0x7f58096ea390>,
#  'homosexualidad': <gensim.models.keyedvectors.Vocab at 0x7f58096e4450>,
#  'hora': <gensim.models.keyedvectors.Vocab at 0x7f58096e1ed0>,
#  'horas': <gensim.models.keyedvectors.Vocab at 0x7f5809721250>,
#  'hoy': <gensim.models.keyedvectors.Vocab at 0x7f580970a5d0>,
#  'huffman': <gensim.models.keyedvectors.Vocab at 0x7f5809709210>,
#  'humano': <gensim.models.keyedvectors.Vocab at 0x7f5809702490>,
#  'humanos': <gensim.models.keyedvectors.Vocab at 0x7f58096e47d0>,
#  'humor': <gensim.models.keyedvectors.Vocab at 0x7f58076a1c90>,
#  'iba': <gensim.models.keyedvectors.Vocab at 0x7f58096e21d0>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f5809709ed0>,
#  'ideas': <gensim.models.keyedvectors.Vocab at 0x7f58076c6c50>,
#  'ido': <gensim.models.keyedvectors.Vocab at 0x7f58076a5ad0>,
#  'igual': <gensim.models.keyedvectors.Vocab at 0x7f5809709dd0>,
#  'imgenes': <gensim.models.keyedvectors.Vocab at 0x7f58076a5390>,
#  'importante': <gensim.models.keyedvectors.Vocab at 0x7f58096e43d0>,
#  'imposible': <gensim.models.keyedvectors.Vocab at 0x7f58096ea510>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f58096d6650>,
#  'incln': <gensim.models.keyedvectors.Vocab at 0x7f58076a5b90>,
#  'incluso': <gensim.models.keyedvectors.Vocab at 0x7f5809709b90>,
#  'increible': <gensim.models.keyedvectors.Vocab at 0x7f58096eacd0>,
#  'infancia': <gensim.models.keyedvectors.Vocab at 0x7f580970aa90>,
#  'informacin': <gensim.models.keyedvectors.Vocab at 0x7f58076a1550>,
#  'inocencia': <gensim.models.keyedvectors.Vocab at 0x7f5809709590>,
#  'inquietudes': <gensim.models.keyedvectors.Vocab at 0x7f58096f3590>,
#  'inspirado': <gensim.models.keyedvectors.Vocab at 0x7f58076a1890>,
#  'instituto': <gensim.models.keyedvectors.Vocab at 0x7f58097023d0>,
#  'intencin': <gensim.models.keyedvectors.Vocab at 0x7f58096e4550>,
#  'intensidad': <gensim.models.keyedvectors.Vocab at 0x7f58096d6310>,
#  'intenta': <gensim.models.keyedvectors.Vocab at 0x7f5809705210>,
#  'interesante': <gensim.models.keyedvectors.Vocab at 0x7f5809721bd0>,
#  'interesantes': <gensim.models.keyedvectors.Vocab at 0x7f58096e2910>,
#  'interior': <gensim.models.keyedvectors.Vocab at 0x7f58076a5e10>,
#  'interpretacin': <gensim.models.keyedvectors.Vocab at 0x7f58076a5690>,
#  'interpretaciones': <gensim.models.keyedvectors.Vocab at 0x7f58096d6d90>,
#  'inters': <gensim.models.keyedvectors.Vocab at 0x7f580970aed0>,
#  'ir': <gensim.models.keyedvectors.Vocab at 0x7f5809705690>,
#  'israel': <gensim.models.keyedvectors.Vocab at 0x7f58096ea350>,
#  'jack': <gensim.models.keyedvectors.Vocab at 0x7f58096e2690>,
#  'jams': <gensim.models.keyedvectors.Vocab at 0x7f58096f3510>,
#  'jedi': <gensim.models.keyedvectors.Vocab at 0x7f58076a5a50>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x7f58096e2050>,
#  'johnny': <gensim.models.keyedvectors.Vocab at 0x7f58076a1290>,
#  'jones': <gensim.models.keyedvectors.Vocab at 0x7f58096f3050>,
#  'joven': <gensim.models.keyedvectors.Vocab at 0x7f5809705490>,
#  'juego': <gensim.models.keyedvectors.Vocab at 0x7f5809705250>,
#  'jugar': <gensim.models.keyedvectors.Vocab at 0x7f5809702a90>,
#  'junto': <gensim.models.keyedvectors.Vocab at 0x7f58076a5490>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x7f58076aa410>,
#  'lado': <gensim.models.keyedvectors.Vocab at 0x7f58096e12d0>,
#  'larga': <gensim.models.keyedvectors.Vocab at 0x7f58096d6050>,
#  'largo': <gensim.models.keyedvectors.Vocab at 0x7f580970aa50>,
#  'ledger': <gensim.models.keyedvectors.Vocab at 0x7f58096e41d0>,
#  'lee': <gensim.models.keyedvectors.Vocab at 0x7f58096e2b90>,
#  'leer': <gensim.models.keyedvectors.Vocab at 0x7f5809705a90>,
#  'lejos': <gensim.models.keyedvectors.Vocab at 0x7f58076a1790>,
#  'lenta': <gensim.models.keyedvectors.Vocab at 0x7f580974cf10>,
#  'libro': <gensim.models.keyedvectors.Vocab at 0x7f5809705510>,
#  'libros': <gensim.models.keyedvectors.Vocab at 0x7f58076a1410>,
#  'llama': <gensim.models.keyedvectors.Vocab at 0x7f5809705550>,
#  'llega': <gensim.models.keyedvectors.Vocab at 0x7f58096e1b90>,
#  'llegan': <gensim.models.keyedvectors.Vocab at 0x7f5809709750>,
#  'llegar': <gensim.models.keyedvectors.Vocab at 0x7f58076a1d50>,
#  'lleno': <gensim.models.keyedvectors.Vocab at 0x7f58096e2790>,
#  'lleva': <gensim.models.keyedvectors.Vocab at 0x7f58096eac50>,
#  'llevar': <gensim.models.keyedvectors.Vocab at 0x7f58096f3fd0>,
#  'logra': <gensim.models.keyedvectors.Vocab at 0x7f58096ea650>,
#  'logrado': <gensim.models.keyedvectors.Vocab at 0x7f58076a1a50>,
#  'lograr': <gensim.models.keyedvectors.Vocab at 0x7f58076a5190>,
#  'ltima': <gensim.models.keyedvectors.Vocab at 0x7f58096d6450>,
#  'ltimo': <gensim.models.keyedvectors.Vocab at 0x7f58096f3890>,
#  'lucha': <gensim.models.keyedvectors.Vocab at 0x7f58096f3f90>,
#  'luego': <gensim.models.keyedvectors.Vocab at 0x7f58076aa250>,
#  'lugar': <gensim.models.keyedvectors.Vocab at 0x7f58076c6910>,
#  'luxaciones': <gensim.models.keyedvectors.Vocab at 0x7f58076a3050>,
#  'madre': <gensim.models.keyedvectors.Vocab at 0x7f5809705e50>,
#  'maestra': <gensim.models.keyedvectors.Vocab at 0x7f58096e2ad0>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x7f5809709d10>,
#  'mala': <gensim.models.keyedvectors.Vocab at 0x7f58096e1f50>,
#  'malas': <gensim.models.keyedvectors.Vocab at 0x7f5809726350>,
#  'malo': <gensim.models.keyedvectors.Vocab at 0x7f58096f3190>,
#  'malos': <gensim.models.keyedvectors.Vocab at 0x7f5809705850>,
#  'manera': <gensim.models.keyedvectors.Vocab at 0x7f58096e2c90>,
#  'mano': <gensim.models.keyedvectors.Vocab at 0x7f58096e2450>,
#  'mantener': <gensim.models.keyedvectors.Vocab at 0x7f58096f3e90>,
#  'mantiene': <gensim.models.keyedvectors.Vocab at 0x7f5809788550>,
#  'mar': <gensim.models.keyedvectors.Vocab at 0x7f58096f3d50>,
#  'mas': <gensim.models.keyedvectors.Vocab at 0x7f58097059d0>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f58076a1c50>,
#  'mayor': <gensim.models.keyedvectors.Vocab at 0x7f5809702fd0>,
#  'mayora': <gensim.models.keyedvectors.Vocab at 0x7f58096e1610>,
#  'mayores': <gensim.models.keyedvectors.Vocab at 0x7f5809709e50>,
#  'mccarthy': <gensim.models.keyedvectors.Vocab at 0x7f58076a55d0>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x7f58096e1f10>,
#  'medida': <gensim.models.keyedvectors.Vocab at 0x7f58076a5510>,
#  'medio': <gensim.models.keyedvectors.Vocab at 0x7f580988bfd0>,
#  'mejor': <gensim.models.keyedvectors.Vocab at 0x7f5809721ed0>,
#  'mejores': <gensim.models.keyedvectors.Vocab at 0x7f5809709b50>,
#  'melissa': <gensim.models.keyedvectors.Vocab at 0x7f58097054d0>,
#  'mencin': <gensim.models.keyedvectors.Vocab at 0x7f58076a1610>,
#  'mendes': <gensim.models.keyedvectors.Vocab at 0x7f58076a3490>,
#  'menor': <gensim.models.keyedvectors.Vocab at 0x7f58076a5890>,
#  'menos': <gensim.models.keyedvectors.Vocab at 0x7f5809721990>,
#  'mensaje': <gensim.models.keyedvectors.Vocab at 0x7f5809709550>,
#  'menudo': <gensim.models.keyedvectors.Vocab at 0x7f58096ead50>,
#  'merece': <gensim.models.keyedvectors.Vocab at 0x7f58096f3610>,
#  'metraje': <gensim.models.keyedvectors.Vocab at 0x7f5809721c10>,
#  'mezcla': <gensim.models.keyedvectors.Vocab at 0x7f58096d6910>,
#  'miedo': <gensim.models.keyedvectors.Vocab at 0x7f580970ac50>,
#  'mientras': <gensim.models.keyedvectors.Vocab at 0x7f58096ea790>,
#  'mil': <gensim.models.keyedvectors.Vocab at 0x7f5809705790>,
#  'minutos': <gensim.models.keyedvectors.Vocab at 0x7f58096e1d50>,
#  'mirada': <gensim.models.keyedvectors.Vocab at 0x7f58076a5090>,
#  'miradas': <gensim.models.keyedvectors.Vocab at 0x7f58096e4050>,
#  'misma': <gensim.models.keyedvectors.Vocab at 0x7f58096f3350>,
#  'mismo': <gensim.models.keyedvectors.Vocab at 0x7f5809705fd0>,
#  'mismos': <gensim.models.keyedvectors.Vocab at 0x7f5809709cd0>,
#  'mitad': <gensim.models.keyedvectors.Vocab at 0x7f58076a3090>,
#  'modo': <gensim.models.keyedvectors.Vocab at 0x7f5809739390>,
#  'momento': <gensim.models.keyedvectors.Vocab at 0x7f58097027d0>,
#  'momentos': <gensim.models.keyedvectors.Vocab at 0x7f58096e2890>,
#  'montaje': <gensim.models.keyedvectors.Vocab at 0x7f5809721290>,
#  'moral': <gensim.models.keyedvectors.Vocab at 0x7f58076a5d90>,
#  'motivo': <gensim.models.keyedvectors.Vocab at 0x7f580970add0>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x7f5809709910>,
#  'ms': <gensim.models.keyedvectors.Vocab at 0x7f58076aa050>,
#  'msica': <gensim.models.keyedvectors.Vocab at 0x7f58096e45d0>,
#  'mucha': <gensim.models.keyedvectors.Vocab at 0x7f5809705590>,
#  'muchas': <gensim.models.keyedvectors.Vocab at 0x7f580974ce10>,
#  'muerte': <gensim.models.keyedvectors.Vocab at 0x7f580974ce50>,
#  'muertos': <gensim.models.keyedvectors.Vocab at 0x7f58096f3a50>,
#  'muestra': <gensim.models.keyedvectors.Vocab at 0x7f58097029d0>,
#  'mujer': <gensim.models.keyedvectors.Vocab at 0x7f580970a750>,
#  'mujeres': <gensim.models.keyedvectors.Vocab at 0x7f5809702850>,
#  'mundo': <gensim.models.keyedvectors.Vocab at 0x7f5809702dd0>,
#  'munich': <gensim.models.keyedvectors.Vocab at 0x7f58096ea150>,
#  'murrow': <gensim.models.keyedvectors.Vocab at 0x7f58076a5550>,
#  'musical': <gensim.models.keyedvectors.Vocab at 0x7f58096ea090>,
#  'nadie': <gensim.models.keyedvectors.Vocab at 0x7f58096e2c10>,
#  'narra': <gensim.models.keyedvectors.Vocab at 0x7f58096e2ed0>,
#  'narracin': <gensim.models.keyedvectors.Vocab at 0x7f5809702150>,
#  'narrada': <gensim.models.keyedvectors.Vocab at 0x7f5809709610>,
#  'narrativa': <gensim.models.keyedvectors.Vocab at 0x7f58076a1950>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x7f5809705ad0>,
#  'naturaleza': <gensim.models.keyedvectors.Vocab at 0x7f58096f3c90>,
#  'necesario': <gensim.models.keyedvectors.Vocab at 0x7f5809702410>,
#  'necesidad': <gensim.models.keyedvectors.Vocab at 0x7f58096e4ed0>,
#  'necesita': <gensim.models.keyedvectors.Vocab at 0x7f580970a0d0>,
#  'negro': <gensim.models.keyedvectors.Vocab at 0x7f58096e1810>,
#  'ngeles': <gensim.models.keyedvectors.Vocab at 0x7f58096d68d0>,
#  'nia': <gensim.models.keyedvectors.Vocab at 0x7f5809705e10>,
#  'nica': <gensim.models.keyedvectors.Vocab at 0x7f58096e4510>,
#  'nicamente': <gensim.models.keyedvectors.Vocab at 0x7f5809709390>,
#  'nico': <gensim.models.keyedvectors.Vocab at 0x7f580970a810>,
#  'ningn': <gensim.models.keyedvectors.Vocab at 0x7f58096e2950>,
#  'ninguna': <gensim.models.keyedvectors.Vocab at 0x7f5809709a50>,
#  'nio': <gensim.models.keyedvectors.Vocab at 0x7f5809702f50>,
#  'nios': <gensim.models.keyedvectors.Vocab at 0x7f5809709e10>,
#  'nivel': <gensim.models.keyedvectors.Vocab at 0x7f5809709890>,
#  'noche': <gensim.models.keyedvectors.Vocab at 0x7f58096f3a10>,
#  'noches': <gensim.models.keyedvectors.Vocab at 0x7f58096e1c90>,
#  'nombre': <gensim.models.keyedvectors.Vocab at 0x7f58096ea990>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x7f58096f3e10>,
#  'nostalgia': <gensim.models.keyedvectors.Vocab at 0x7f58096e4b10>,
#  'nota': <gensim.models.keyedvectors.Vocab at 0x7f58096d60d0>,
#  'notable': <gensim.models.keyedvectors.Vocab at 0x7f58076a5fd0>,
#  'novela': <gensim.models.keyedvectors.Vocab at 0x7f5809702a50>,
#  'nueva': <gensim.models.keyedvectors.Vocab at 0x7f58096d6250>,
#  'nuevo': <gensim.models.keyedvectors.Vocab at 0x7f5809709810>,
#  'nunca': <gensim.models.keyedvectors.Vocab at 0x7f58097097d0>,
#  'obra': <gensim.models.keyedvectors.Vocab at 0x7f5809709350>,
#  'obras': <gensim.models.keyedvectors.Vocab at 0x7f58096e4bd0>,
#  'obvio': <gensim.models.keyedvectors.Vocab at 0x7f58076a1850>,
#  'ocasin': <gensim.models.keyedvectors.Vocab at 0x7f58096e10d0>,
#  'ocasiones': <gensim.models.keyedvectors.Vocab at 0x7f58097025d0>,
#  'ocurre': <gensim.models.keyedvectors.Vocab at 0x7f58096f31d0>,
#  'odio': <gensim.models.keyedvectors.Vocab at 0x7f58076a3390>,
#  'ofrece': <gensim.models.keyedvectors.Vocab at 0x7f58096e4350>,
#  'opcin': <gensim.models.keyedvectors.Vocab at 0x7f580970ab10>,
#  'opinin': <gensim.models.keyedvectors.Vocab at 0x7f58076a1150>,
#  'oportunidad': <gensim.models.keyedvectors.Vocab at 0x7f58076a5e90>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x7f58076c6a50>,
#  'oscar': <gensim.models.keyedvectors.Vocab at 0x7f58096eaa50>,
#  'padre': <gensim.models.keyedvectors.Vocab at 0x7f58097056d0>,
#  'palabras': <gensim.models.keyedvectors.Vocab at 0x7f58076a3210>,
#  'palestino': <gensim.models.keyedvectors.Vocab at 0x7f58096ea210>,
#  'palestinos': <gensim.models.keyedvectors.Vocab at 0x7f58096ea3d0>,
#  'pantalla': <gensim.models.keyedvectors.Vocab at 0x7f58076c6b90>,
#  'papel': <gensim.models.keyedvectors.Vocab at 0x7f58096e1110>,
#  'papeles': <gensim.models.keyedvectors.Vocab at 0x7f58096e1050>,
#  'par': <gensim.models.keyedvectors.Vocab at 0x7f58096e20d0>,
#  'parece': <gensim.models.keyedvectors.Vocab at 0x7f5809788850>,
#  'parecen': <gensim.models.keyedvectors.Vocab at 0x7f58096e4390>,
#  'parecer': <gensim.models.keyedvectors.Vocab at 0x7f58096e2c50>,
#  'pareja': <gensim.models.keyedvectors.Vocab at 0x7f58096d6b50>,
#  'parte': <gensim.models.keyedvectors.Vocab at 0x7f5809705a10>,
#  'partes': <gensim.models.keyedvectors.Vocab at 0x7f580974cf50>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x7f58096f3410>,
#  'partir': <gensim.models.keyedvectors.Vocab at 0x7f58096f3790>,
#  'pas': <gensim.models.keyedvectors.Vocab at 0x7f58096eaf90>,
#  'pasa': <gensim.models.keyedvectors.Vocab at 0x7f58096e1450>,
#  'pasado': <gensim.models.keyedvectors.Vocab at 0x7f5809705f90>,
#  'pasan': <gensim.models.keyedvectors.Vocab at 0x7f5809709050>,
#  'pasando': <gensim.models.keyedvectors.Vocab at 0x7f58096ea590>,
#  'pasar': <gensim.models.keyedvectors.Vocab at 0x7f58076a5990>,
#  'pasin': <gensim.models.keyedvectors.Vocab at 0x7f58096e2f10>,
#  'paso': <gensim.models.keyedvectors.Vocab at 0x7f58076a1690>,
#  'paul': <gensim.models.keyedvectors.Vocab at 0x7f58096d6790>,
#  'paz': <gensim.models.keyedvectors.Vocab at 0x7f5809721810>,
#  'pblico': <gensim.models.keyedvectors.Vocab at 0x7f580970af10>,
#  'pelcula': <gensim.models.keyedvectors.Vocab at 0x7f580970a490>,
#  'pelculas': <gensim.models.keyedvectors.Vocab at 0x7f5809709650>,
#  'peli': <gensim.models.keyedvectors.Vocab at 0x7f5809705d10>,
#  'pelicula': <gensim.models.keyedvectors.Vocab at 0x7f5809705f50>,
#  'peliculas': <gensim.models.keyedvectors.Vocab at 0x7f5809709d50>,
#  'peliculn': <gensim.models.keyedvectors.Vocab at 0x7f5809709090>,
#  'pelis': <gensim.models.keyedvectors.Vocab at 0x7f5809709ad0>,
#  'pelo': <gensim.models.keyedvectors.Vocab at 0x7f5809705b90>,
#  'pena': <gensim.models.keyedvectors.Vocab at 0x7f58076a5b10>,
#  'pensar': <gensim.models.keyedvectors.Vocab at 0x7f58096e2cd0>,
#  'peor': <gensim.models.keyedvectors.Vocab at 0x7f58096d6c10>,
#  'perfectamente': <gensim.models.keyedvectors.Vocab at 0x7f58076a1310>,
#  'periodismo': <gensim.models.keyedvectors.Vocab at 0x7f58076a3110>,
#  'periodista': <gensim.models.keyedvectors.Vocab at 0x7f58076a3150>,
#  'persona': <gensim.models.keyedvectors.Vocab at 0x7f5809702d50>,
#  'personaje': <gensim.models.keyedvectors.Vocab at 0x7f5809709450>,
#  'personajes': <gensim.models.keyedvectors.Vocab at 0x7f58096e11d0>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x7f58096e2750>,
#  'personalidad': <gensim.models.keyedvectors.Vocab at 0x7f58076a5d50>,
#  'personas': <gensim.models.keyedvectors.Vocab at 0x7f58096d6cd0>,
#  'pesadilla': <gensim.models.keyedvectors.Vocab at 0x7f58076a5dd0>,
#  'pesar': <gensim.models.keyedvectors.Vocab at 0x7f5809702bd0>,
#  'pese': <gensim.models.keyedvectors.Vocab at 0x7f58076a35d0>,
#  'peter': <gensim.models.keyedvectors.Vocab at 0x7f58076a3410>,
#  'piel': <gensim.models.keyedvectors.Vocab at 0x7f580970a1d0>,
#  'placer': <gensim.models.keyedvectors.Vocab at 0x7f58076a5310>,
#  'plano': <gensim.models.keyedvectors.Vocab at 0x7f58096e1a50>,
#  'planos': <gensim.models.keyedvectors.Vocab at 0x7f58096e27d0>,
#  'pobre': <gensim.models.keyedvectors.Vocab at 0x7f58076a57d0>,
#  'poca': <gensim.models.keyedvectors.Vocab at 0x7f58096e2f90>,
#  'pocas': <gensim.models.keyedvectors.Vocab at 0x7f58096e4190>,
#  'pocos': <gensim.models.keyedvectors.Vocab at 0x7f58096d66d0>,
#  'podemos': <gensim.models.keyedvectors.Vocab at 0x7f5809739d10>,
#  'poder': <gensim.models.keyedvectors.Vocab at 0x7f58096e1dd0>,
#  'podr': <gensim.models.keyedvectors.Vocab at 0x7f5809709790>,
#  'podra': <gensim.models.keyedvectors.Vocab at 0x7f58096d6f10>,
#  'polica': <gensim.models.keyedvectors.Vocab at 0x7f58096d6e10>,
#  'polmica': <gensim.models.keyedvectors.Vocab at 0x7f58097099d0>,
#  'poltica': <gensim.models.keyedvectors.Vocab at 0x7f58096f3310>,
#  'polticos': <gensim.models.keyedvectors.Vocab at 0x7f58096f3390>,
#  'pone': <gensim.models.keyedvectors.Vocab at 0x7f5809705cd0>,
#  'poquito': <gensim.models.keyedvectors.Vocab at 0x7f5809705e90>,
#  'porqu': <gensim.models.keyedvectors.Vocab at 0x7f58096eab10>,
#  'posible': <gensim.models.keyedvectors.Vocab at 0x7f5809705750>,
#  'posibles': <gensim.models.keyedvectors.Vocab at 0x7f5809705b10>,
#  'postura': <gensim.models.keyedvectors.Vocab at 0x7f58096f33d0>,
#  'potter': <gensim.models.keyedvectors.Vocab at 0x7f58096ea810>,
#  'precisamente': <gensim.models.keyedvectors.Vocab at 0x7f580970a150>,
#  'pregunta': <gensim.models.keyedvectors.Vocab at 0x7f58096eab90>,
#  'prejuicios': <gensim.models.keyedvectors.Vocab at 0x7f58097093d0>,
#  'premios': <gensim.models.keyedvectors.Vocab at 0x7f58096e2bd0>,
#  'presencia': <gensim.models.keyedvectors.Vocab at 0x7f5809709710>,
#  'presenta': <gensim.models.keyedvectors.Vocab at 0x7f58076a1a10>,
#  'presente': <gensim.models.keyedvectors.Vocab at 0x7f58076a1ed0>,
#  'previsible': <gensim.models.keyedvectors.Vocab at 0x7f58076c6f50>,
#  'prima': <gensim.models.keyedvectors.Vocab at 0x7f58076c6bd0>,
#  'primer': <gensim.models.keyedvectors.Vocab at 0x7f58076c68d0>,
#  'primera': <gensim.models.keyedvectors.Vocab at 0x7f58076c6710>,
#  'primero': <gensim.models.keyedvectors.Vocab at 0x7f58096e48d0>,
#  'principal': <gensim.models.keyedvectors.Vocab at 0x7f58096ea4d0>,
#  'principales': <gensim.models.keyedvectors.Vocab at 0x7f58096e1fd0>,
#  'principalmente': <gensim.models.keyedvectors.Vocab at 0x7f58096e4b50>,
#  'principio': <gensim.models.keyedvectors.Vocab at 0x7f58076c6d50>,
#  'problema': <gensim.models.keyedvectors.Vocab at 0x7f58076c6f90>,
#  'problemas': <gensim.models.keyedvectors.Vocab at 0x7f58096ea110>,
#  'profunda': <gensim.models.keyedvectors.Vocab at 0x7f58076a5750>,
#  'profundizar': <gensim.models.keyedvectors.Vocab at 0x7f58096f3450>,
#  'programa': <gensim.models.keyedvectors.Vocab at 0x7f58076a5610>,
#  'propia': <gensim.models.keyedvectors.Vocab at 0x7f5809721b90>,
#  'propias': <gensim.models.keyedvectors.Vocab at 0x7f58096e4f10>,
#  'propio': <gensim.models.keyedvectors.Vocab at 0x7f58076c66d0>,
#  'propios': <gensim.models.keyedvectors.Vocab at 0x7f58076a5810>,
#  'protagonista': <gensim.models.keyedvectors.Vocab at 0x7f5809721410>,
#  'protagonistas': <gensim.models.keyedvectors.Vocab at 0x7f58096d6a90>,
#  'provoca': <gensim.models.keyedvectors.Vocab at 0x7f5809709190>,
#  'provocar': <gensim.models.keyedvectors.Vocab at 0x7f58096e2850>,
#  'pueda': <gensim.models.keyedvectors.Vocab at 0x7f58096e1090>,
#  'puede': <gensim.models.keyedvectors.Vocab at 0x7f580970a390>,
#  'pueden': <gensim.models.keyedvectors.Vocab at 0x7f5809702890>,
#  'puedo': <gensim.models.keyedvectors.Vocab at 0x7f58096e22d0>,
#  'pues': <gensim.models.keyedvectors.Vocab at 0x7f58097055d0>,
#  'puesto': <gensim.models.keyedvectors.Vocab at 0x7f5809705dd0>,
#  'puetazo': <gensim.models.keyedvectors.Vocab at 0x7f58076a5f10>,
#  'punto': <gensim.models.keyedvectors.Vocab at 0x7f580970a2d0>,
#  'puntos': <gensim.models.keyedvectors.Vocab at 0x7f58076a12d0>,
#  'puramente': <gensim.models.keyedvectors.Vocab at 0x7f5809709690>,
#  'puta': <gensim.models.keyedvectors.Vocab at 0x7f5809709e90>,
#  'qu': <gensim.models.keyedvectors.Vocab at 0x7f5809702c90>,
#  'queda': <gensim.models.keyedvectors.Vocab at 0x7f5809721710>,
#  'querer': <gensim.models.keyedvectors.Vocab at 0x7f58096d6c90>,
#  'querido': <gensim.models.keyedvectors.Vocab at 0x7f580970a7d0>,
#  'quiere': <gensim.models.keyedvectors.Vocab at 0x7f58096f3110>,
#  'quieren': <gensim.models.keyedvectors.Vocab at 0x7f5809702810>,
#  'quin': <gensim.models.keyedvectors.Vocab at 0x7f58096eaa10>,
#  'quiz': <gensim.models.keyedvectors.Vocab at 0x7f58097092d0>,
#  'quizs': <gensim.models.keyedvectors.Vocab at 0x7f58096d6ed0>,
#  'rato': <gensim.models.keyedvectors.Vocab at 0x7f58096ea5d0>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f58097214d0>,
#  'realidad': <gensim.models.keyedvectors.Vocab at 0x7f58097218d0>,
#  'realista': <gensim.models.keyedvectors.Vocab at 0x7f58076a5910>,
#  'realiza': <gensim.models.keyedvectors.Vocab at 0x7f58096e4fd0>,
#  'realmente': <gensim.models.keyedvectors.Vocab at 0x7f580970a350>,
#  'recomiendo': <gensim.models.keyedvectors.Vocab at 0x7f58096f3090>,
#  'reconocer': <gensim.models.keyedvectors.Vocab at 0x7f58096d62d0>,
#  'recuerda': <gensim.models.keyedvectors.Vocab at 0x7f58096d6d10>,
#  'reflexin': <gensim.models.keyedvectors.Vocab at 0x7f58096f38d0>,
#  'reflexionar': <gensim.models.keyedvectors.Vocab at 0x7f58076a13d0>,
#  'relacin': <gensim.models.keyedvectors.Vocab at 0x7f58096d63d0>,
#  'relaciones': <gensim.models.keyedvectors.Vocab at 0x7f58096f3f10>,
#  'relato': <gensim.models.keyedvectors.Vocab at 0x7f5809721590>,
#  'reparto': <gensim.models.keyedvectors.Vocab at 0x7f58076aa090>,
#  'representa': <gensim.models.keyedvectors.Vocab at 0x7f58096e2d10>,
#  'resto': <gensim.models.keyedvectors.Vocab at 0x7f5809788690>,
#  'resulta': <gensim.models.keyedvectors.Vocab at 0x7f58097026d0>,
#  'resultar': <gensim.models.keyedvectors.Vocab at 0x7f5809702750>,
#  'resumen': <gensim.models.keyedvectors.Vocab at 0x7f58076a51d0>,
#  'retorno': <gensim.models.keyedvectors.Vocab at 0x7f58076a5a90>,
#  'retrata': <gensim.models.keyedvectors.Vocab at 0x7f58076a3450>,
#  'ricos': <gensim.models.keyedvectors.Vocab at 0x7f58096d69d0>,
#  'risa': <gensim.models.keyedvectors.Vocab at 0x7f58096eaf10>,
#  'ritmo': <gensim.models.keyedvectors.Vocab at 0x7f58096d6d50>,
#  'robert': <gensim.models.keyedvectors.Vocab at 0x7f58096e1b50>,
#  'rollo': <gensim.models.keyedvectors.Vocab at 0x7f58096d6210>,
#  'romance': <gensim.models.keyedvectors.Vocab at 0x7f58076a1190>,
#  'romero': <gensim.models.keyedvectors.Vocab at 0x7f58096f39d0>,
#  'rosa': <gensim.models.keyedvectors.Vocab at 0x7f58076a59d0>,
#  'rumbo': <gensim.models.keyedvectors.Vocab at 0x7f58076a5250>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f58097212d0>,
#  'sabe': <gensim.models.keyedvectors.Vocab at 0x7f5809709f90>,
#  'saber': <gensim.models.keyedvectors.Vocab at 0x7f58096e1790>,
#  'sabes': <gensim.models.keyedvectors.Vocab at 0x7f58096e4210>,
#  'sabido': <gensim.models.keyedvectors.Vocab at 0x7f58096e4410>,
#  'sacar': <gensim.models.keyedvectors.Vocab at 0x7f58096e4890>,
#  'sale': <gensim.models.keyedvectors.Vocab at 0x7f58076c6950>,
#  'salir': <gensim.models.keyedvectors.Vocab at 0x7f58096eaf50>,
#  'sangre': <gensim.models.keyedvectors.Vocab at 0x7f58076a1dd0>,
#  'saraband': <gensim.models.keyedvectors.Vocab at 0x7f58076a3710>,
#  'secreto': <gensim.models.keyedvectors.Vocab at 0x7f58096ea310>,
#  'secretos': <gensim.models.keyedvectors.Vocab at 0x7f580970a9d0>,
#  'secuencias': <gensim.models.keyedvectors.Vocab at 0x7f58096e1290>,
#  'segn': <gensim.models.keyedvectors.Vocab at 0x7f58076c6850>,
#  'seguir': <gensim.models.keyedvectors.Vocab at 0x7f58096e4910>,
#  'segunda': <gensim.models.keyedvectors.Vocab at 0x7f5809705a50>,
#  'senador': <gensim.models.keyedvectors.Vocab at 0x7f58076a5590>,
#  'sencillo': <gensim.models.keyedvectors.Vocab at 0x7f58076a54d0>,
#  'sensacin': <gensim.models.keyedvectors.Vocab at 0x7f580970a990>,
#  'sentimiento': <gensim.models.keyedvectors.Vocab at 0x7f58096e40d0>,
#  'sentimientos': <gensim.models.keyedvectors.Vocab at 0x7f58096f3710>,
#  'sentir': <gensim.models.keyedvectors.Vocab at 0x7f58096f3550>,
#  'seor': <gensim.models.keyedvectors.Vocab at 0x7f5809702510>,
#  'ser': <gensim.models.keyedvectors.Vocab at 0x7f5809702910>,
#  'sera': <gensim.models.keyedvectors.Vocab at 0x7f5809709a10>,
#  'seres': <gensim.models.keyedvectors.Vocab at 0x7f58096f3ad0>,
#  'seria': <gensim.models.keyedvectors.Vocab at 0x7f58096e1c50>,
#  'serie': <gensim.models.keyedvectors.Vocab at 0x7f5809705890>,
#  'sern': <gensim.models.keyedvectors.Vocab at 0x7f58076a5350>,
#  'sexo': <gensim.models.keyedvectors.Vocab at 0x7f58097052d0>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x7f580970ab50>,
#  'seymour': <gensim.models.keyedvectors.Vocab at 0x7f58076a1f90>,
#  'si': <gensim.models.keyedvectors.Vocab at 0x7f58076c6810>,
#  'sido': <gensim.models.keyedvectors.Vocab at 0x7f58096e2a50>,
#  'siempre': <gensim.models.keyedvectors.Vocab at 0x7f580970a790>,
#  'siendo': <gensim.models.keyedvectors.Vocab at 0x7f58096e44d0>,
#  'sigue': <gensim.models.keyedvectors.Vocab at 0x7f58096e4810>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x7f58076c6fd0>,
#  'simplemente': <gensim.models.keyedvectors.Vocab at 0x7f580970a410>,
#  'sino': <gensim.models.keyedvectors.Vocab at 0x7f58096e1350>,
#  'siquiera': <gensim.models.keyedvectors.Vocab at 0x7f58076c6c90>,
#  'situacin': <gensim.models.keyedvectors.Vocab at 0x7f58096d6bd0>,
#  'situaciones': <gensim.models.keyedvectors.Vocab at 0x7f58096e2990>,
#  'slo': <gensim.models.keyedvectors.Vocab at 0x7f58076aa1d0>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7f580970ac10>,
#  'sociales': <gensim.models.keyedvectors.Vocab at 0x7f58096e4150>,
#  'sociedad': <gensim.models.keyedvectors.Vocab at 0x7f5809705350>,
#  'sof': <gensim.models.keyedvectors.Vocab at 0x7f58076a3190>,
#  'solamente': <gensim.models.keyedvectors.Vocab at 0x7f58076c69d0>,
#  'solo': <gensim.models.keyedvectors.Vocab at 0x7f5809709d90>,
#  'sonora': <gensim.models.keyedvectors.Vocab at 0x7f58096ea8d0>,
#  'sorprende': <gensim.models.keyedvectors.Vocab at 0x7f58096e2a10>,
#  'sorpresa': <gensim.models.keyedvectors.Vocab at 0x7f58096d6f90>,
#  'spiderman': <gensim.models.keyedvectors.Vocab at 0x7f58076a1b10>,
#  'spielberg': <gensim.models.keyedvectors.Vocab at 0x7f58076aa290>,
#  'sta': <gensim.models.keyedvectors.Vocab at 0x7f58096e2a90>,
#  'ste': <gensim.models.keyedvectors.Vocab at 0x7f58096d6e90>,
#  'suele': <gensim.models.keyedvectors.Vocab at 0x7f58096f3210>,
#  'suelen': <gensim.models.keyedvectors.Vocab at 0x7f58096d6690>,
#  'sueo': <gensim.models.keyedvectors.Vocab at 0x7f58096ea0d0>,
#  'suerte': <gensim.models.keyedvectors.Vocab at 0x7f58096e1cd0>,
#  'suficiente': <gensim.models.keyedvectors.Vocab at 0x7f58097094d0>,
#  'sufrido': <gensim.models.keyedvectors.Vocab at 0x7f58076a1510>,
#  'supuesto': <gensim.models.keyedvectors.Vocab at 0x7f58076a1f10>,
#  'tal': <gensim.models.keyedvectors.Vocab at 0x7f58096e2110>,
#  'talento': <gensim.models.keyedvectors.Vocab at 0x7f5809721310>,
#  'tambien': <gensim.models.keyedvectors.Vocab at 0x7f5809705c10>,
#  'tambin': <gensim.models.keyedvectors.Vocab at 0x7f58097bb150>,
#  'tampoco': <gensim.models.keyedvectors.Vocab at 0x7f58096d6410>,
#  'tan': <gensim.models.keyedvectors.Vocab at 0x7f5809702710>,
#  'tanta': <gensim.models.keyedvectors.Vocab at 0x7f58096f3290>,
#  'tarde': <gensim.models.keyedvectors.Vocab at 0x7f58096e4950>,
#  'teatro': <gensim.models.keyedvectors.Vocab at 0x7f58076a1b90>,
#  'tele': <gensim.models.keyedvectors.Vocab at 0x7f58076a1ad0>,
#  'televisin': <gensim.models.keyedvectors.Vocab at 0x7f58096e1c10>,
#  'tema': <gensim.models.keyedvectors.Vocab at 0x7f58076c6b50>,
#  'temas': <gensim.models.keyedvectors.Vocab at 0x7f5809709950>,
#  'tena': <gensim.models.keyedvectors.Vocab at 0x7f58096e28d0>,
#  'tener': <gensim.models.keyedvectors.Vocab at 0x7f58096e2e50>,
#  'tensin': <gensim.models.keyedvectors.Vocab at 0x7f58096e1910>,
#  'tercera': <gensim.models.keyedvectors.Vocab at 0x7f5809705950>,
#  'termina': <gensim.models.keyedvectors.Vocab at 0x7f58096e4490>,
#  'terminar': <gensim.models.keyedvectors.Vocab at 0x7f58076a5bd0>,
#  'terror': <gensim.models.keyedvectors.Vocab at 0x7f58096e1f90>,
#  'terrorista': <gensim.models.keyedvectors.Vocab at 0x7f58096ea1d0>,
#  'terroristas': <gensim.models.keyedvectors.Vocab at 0x7f58076a17d0>,
#  'testamento': <gensim.models.keyedvectors.Vocab at 0x7f58076a36d0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f58096d65d0>,
#  'tiempo': <gensim.models.keyedvectors.Vocab at 0x7f58096e1ad0>,
#  'tiempos': <gensim.models.keyedvectors.Vocab at 0x7f58076a3290>,
#  'tierra': <gensim.models.keyedvectors.Vocab at 0x7f58096f3950>,
#  'tipo': <gensim.models.keyedvectors.Vocab at 0x7f5809705990>,
#  'toby': <gensim.models.keyedvectors.Vocab at 0x7f58076a3650>,
#  'toca': <gensim.models.keyedvectors.Vocab at 0x7f58076c6d10>,
#  'toda': <gensim.models.keyedvectors.Vocab at 0x7f58076aa110>,
#  'todas': <gensim.models.keyedvectors.Vocab at 0x7f5809709a90>,
#  'todava': <gensim.models.keyedvectors.Vocab at 0x7f58096e2250>,
#  'tom': <gensim.models.keyedvectors.Vocab at 0x7f58096e2490>,
#  'tommy': <gensim.models.keyedvectors.Vocab at 0x7f58096eafd0>,
#  'tono': <gensim.models.keyedvectors.Vocab at 0x7f58076c6e10>,
#  'tormento': <gensim.models.keyedvectors.Vocab at 0x7f58076a5e50>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f5809705c90>,
#  'totalidad': <gensim.models.keyedvectors.Vocab at 0x7f58076a3750>,
#  'totalmente': <gensim.models.keyedvectors.Vocab at 0x7f58096d6390>,
#  'tpico': <gensim.models.keyedvectors.Vocab at 0x7f580970a050>,
#  'tpicos': <gensim.models.keyedvectors.Vocab at 0x7f58096d6490>,
#  'trabajo': <gensim.models.keyedvectors.Vocab at 0x7f58096f3250>,
#  'trama': <gensim.models.keyedvectors.Vocab at 0x7f58096eac90>,
#  'transexual': <gensim.models.keyedvectors.Vocab at 0x7f58076c6ad0>,
#  'transmitir': <gensim.models.keyedvectors.Vocab at 0x7f58097051d0>,
#  'tras': <gensim.models.keyedvectors.Vocab at 0x7f58096e1d10>,
#  'trata': <gensim.models.keyedvectors.Vocab at 0x7f580970ad50>,
#  'tratamiento': <gensim.models.keyedvectors.Vocab at 0x7f58096ea610>,
#  'tratar': <gensim.models.keyedvectors.Vocab at 0x7f58076c6a10>,
#  'tratarse': <gensim.models.keyedvectors.Vocab at 0x7f58076a1f50>,
#  'travs': <gensim.models.keyedvectors.Vocab at 0x7f58076a5450>,
#  'tres': <gensim.models.keyedvectors.Vocab at 0x7f58096e26d0>,
#  'truman': <gensim.models.keyedvectors.Vocab at 0x7f58076a56d0>,
#  'ttulo': <gensim.models.keyedvectors.Vocab at 0x7f5809721d10>,
#  'twist': <gensim.models.keyedvectors.Vocab at 0x7f58096e4c90>,
#  'unas': <gensim.models.keyedvectors.Vocab at 0x7f5809702b90>,
#  'unidos': <gensim.models.keyedvectors.Vocab at 0x7f58096d6950>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x7f5809702c50>,
#  'v': <gensim.models.keyedvectors.Vocab at 0x7f58096e2510>,
#  'va': <gensim.models.keyedvectors.Vocab at 0x7f580970ae50>,
#  'vaco': <gensim.models.keyedvectors.Vocab at 0x7f58076a19d0>,
#  'valle': <gensim.models.keyedvectors.Vocab at 0x7f58076a5b50>,
#  'valverde': <gensim.models.keyedvectors.Vocab at 0x7f5809705190>,
#  'vamos': <gensim.models.keyedvectors.Vocab at 0x7f5809702e50>,
#  'vampiros': <gensim.models.keyedvectors.Vocab at 0x7f58096e4c10>,
#  'van': <gensim.models.keyedvectors.Vocab at 0x7f580970aa10>,
#  'vaqueros': <gensim.models.keyedvectors.Vocab at 0x7f58096e2e90>,
#  'varias': <gensim.models.keyedvectors.Vocab at 0x7f58076a53d0>,
#  'varios': <gensim.models.keyedvectors.Vocab at 0x7f58076a1cd0>,
#  'vctimas': <gensim.models.keyedvectors.Vocab at 0x7f58096f35d0>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7f5809702990>,
#  'vea': <gensim.models.keyedvectors.Vocab at 0x7f5809702ed0>,
#  'veces': <gensim.models.keyedvectors.Vocab at 0x7f580970a090>,
#  'vemos': <gensim.models.keyedvectors.Vocab at 0x7f5809702d10>,
#  'ven': <gensim.models.keyedvectors.Vocab at 0x7f58096d6a10>,
#  'venganza': <gensim.models.keyedvectors.Vocab at 0x7f58096f30d0>,
#  'veo': <gensim.models.keyedvectors.Vocab at 0x7f5809705b50>,
#  'ver': <gensim.models.keyedvectors.Vocab at 0x7f58076c6790>,
#  'verdad': <gensim.models.keyedvectors.Vocab at 0x7f5809702e90>,
#  'verdadera': <gensim.models.keyedvectors.Vocab at 0x7f58097090d0>,
#  'verdaderamente': <gensim.models.keyedvectors.Vocab at 0x7f58096e13d0>,
#  'verdadero': <gensim.models.keyedvectors.Vocab at 0x7f58076c6cd0>,
#  'verla': <gensim.models.keyedvectors.Vocab at 0x7f58096e1490>,
#  'versin': <gensim.models.keyedvectors.Vocab at 0x7f5809721550>,
#  'vez': <gensim.models.keyedvectors.Vocab at 0x7f5809702550>,
#  'vi': <gensim.models.keyedvectors.Vocab at 0x7f58076a1490>,
#  'viaje': <gensim.models.keyedvectors.Vocab at 0x7f580970a690>,
#  'vida': <gensim.models.keyedvectors.Vocab at 0x7f5809705390>,
#  'vidas': <gensim.models.keyedvectors.Vocab at 0x7f58096e2350>,
#  'vieja': <gensim.models.keyedvectors.Vocab at 0x7f58076a1bd0>,
#  'viendo': <gensim.models.keyedvectors.Vocab at 0x7f580970a450>,
#  'viene': <gensim.models.keyedvectors.Vocab at 0x7f58096d6810>,
#  'violencia': <gensim.models.keyedvectors.Vocab at 0x7f58076a1750>,
#  'violenta': <gensim.models.keyedvectors.Vocab at 0x7f5809721f90>,
#  'virtudes': <gensim.models.keyedvectors.Vocab at 0x7f58076a52d0>,
#  'vista': <gensim.models.keyedvectors.Vocab at 0x7f58096ea690>,
#  'visto': <gensim.models.keyedvectors.Vocab at 0x7f58097bb2d0>,
#  'visual': <gensim.models.keyedvectors.Vocab at 0x7f58076a15d0>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x7f58096d6a50>,
#  'vivir': <gensim.models.keyedvectors.Vocab at 0x7f5809702ad0>,
#  'volver': <gensim.models.keyedvectors.Vocab at 0x7f5809709c50>,
#  'voy': <gensim.models.keyedvectors.Vocab at 0x7f580970ab90>,
#  'voz': <gensim.models.keyedvectors.Vocab at 0x7f5809702590>,
#  'vuelve': <gensim.models.keyedvectors.Vocab at 0x7f58096e1150>,
#  'wainwright': <gensim.models.keyedvectors.Vocab at 0x7f58096e2210>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f58076a37d0>,
#  'zombies': <gensim.models.keyedvectors.Vocab at 0x7f58096f3a90>}

# %%
modelow2v["violencia"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.0055624 , -0.02393752, -0.02665151, -0.02622498, -0.01279464,
#        -0.01103592, -0.02126869, -0.07439411,  0.0022387 ,  0.01273191,
#         0.01196193,  0.00278178,  0.03072484, -0.00504989, -0.03541775,
#        -0.00886391,  0.00963297, -0.01844669, -0.03500266, -0.00279269,
#         0.05998901, -0.00021725,  0.00608461, -0.01692653,  0.04941243,
#         0.02406043,  0.03406216,  0.01713356,  0.05026969,  0.01990461,
#        -0.0718488 ,  0.05492964,  0.02781459, -0.02885795, -0.02491877,
#         0.04498044,  0.0189094 , -0.01565269, -0.03802942, -0.01047314,
#        -0.02789842,  0.00425602,  0.01410411,  0.01550606, -0.02653388,
#         0.04560884,  0.00781917, -0.00781311, -0.01317018,  0.05127097,
#        -0.06823833, -0.00451342,  0.01782925, -0.03079997,  0.02103077,
#        -0.0131025 ,  0.00574865,  0.03288058, -0.00594085, -0.01443371,
#        -0.02052822, -0.00731464,  0.0170196 , -0.0024592 ,  0.01292726,
#         0.02331564,  0.01707995, -0.01882094,  0.01024506, -0.00995206,
#        -0.00139727,  0.0349529 ,  0.02269806,  0.05058282,  0.00435239,
#         0.02787517, -0.01204079,  0.02315339, -0.02591507,  0.00271662,
#        -0.0078792 , -0.02244362,  0.01502213,  0.00754833, -0.02918166,
#        -0.00799707,  0.02222045, -0.01495811, -0.02162796,  0.03722763,
#        -0.05720495, -0.05804928,  0.00312846, -0.01894681,  0.01874714,
#         0.00747987,  0.03536581,  0.04528308, -0.00886509, -0.04128669],
#       dtype=float32)

# %%
modelow2v.wv.most_similar('violencia')
# Out:
# [('pelcula', 0.9938942790031433),
#  ('ver', 0.9937605857849121),
#  ('ser', 0.9937481880187988),
#  ('vez', 0.9937158226966858),
#  ('historia', 0.9936923980712891),
#  ('ms', 0.9936090707778931),
#  ('da', 0.9934596419334412),
#  ('ello', 0.9933630228042603),
#  ('si', 0.9933610558509827),
#  ('film', 0.9932942986488342)]

# %% [markdown]
# #Pysentimiento

# %% [markdown]
# Una biblioteca basada en Transformer para tareas de SocialNLP.
#
# Actualmente admite:
#
# * Análisis de Sentimiento (Español, Inglés)
#
# * Análisis de emociones (español, inglés)
#
# * Detección de discursos de odio (español, inglés)

# %%
# !pip install pysentimiento
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pysentimiento
#   Downloading pysentimiento-0.3.2-py3-none-any.whl (20 kB)
# Requirement already satisfied: sklearn<0.1,>=0.0 in /usr/local/lib/python3.7/dist-packages (from pysentimiento) (0.0)
# Requirement already satisfied: torch<2.0.0,>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from pysentimiento) (1.11.0+cu113)
# Collecting transformers<5.0.0,>=4.11.3
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 10.7 MB/s
# Collecting datasets<2.0.0,>=1.13.3
#   Downloading datasets-1.18.4-py3-none-any.whl (312 kB)
#      |████████████████████████████████| 312 kB 70.7 MB/s
# Collecting emoji<2.0.0,>=1.6.1
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 71.2 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (1.21.6)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 13.5 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 53.6 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (2.23.0)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 73.1 MB/s
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 71.9 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (4.11.4)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (6.0.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (4.64.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (21.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (0.3.5.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (0.70.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets<2.0.0,>=1.13.3->pysentimiento) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets<2.0.0,>=1.13.3->pysentimiento) (3.7.1)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 62.5 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets<2.0.0,>=1.13.3->pysentimiento) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (2.10)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 48.6 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn<0.1,>=0.0->pysentimiento) (1.0.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 25.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.11.3->pysentimiento) (2022.6.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (2.0.12)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 75.8 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 74.9 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.6 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets<2.0.0,>=1.13.3->pysentimiento) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (1.15.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn<0.1,>=0.0->pysentimiento) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn<0.1,>=0.0->pysentimiento) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn<0.1,>=0.0->pysentimiento) (1.1.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=ecf4728de32b35b86df9a2ddd2930f9c32f8708a0554047d42ec87b13634b4b1
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, pyyaml, fsspec, aiohttp, xxhash, tokenizers, responses, huggingface-hub, transformers, emoji, datasets, pysentimiento
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-1.18.4 emoji-1.7.0 frozenlist-1.3.0 fsspec-2022.5.0 huggingface-hub-0.8.1 multidict-6.0.2 pysentimiento-0.3.2 pyyaml-6.0 responses-0.18.0 tokenizers-0.12.1 transformers-4.20.1 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2

# %%
from pysentimiento import create_analyzer

# %%
asentiment = create_analyzer(task="sentiment", lang='es')
# Out:
# loading file https://huggingface.co/pysentimiento/robertuito-sentiment-analysis/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/47dd2d3180a6186d30715516321375322e3a84d5e4656762e083091bbb5d5dc4.0843b07596b388e054bae078721182b4846b9e28a7bbf04d7079b274f8613ae3
# loading file https://huggingface.co/pysentimiento/robertuito-sentiment-analysis/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/pysentimiento/robertuito-sentiment-analysis/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/25e0e805456d2786a12b70b86278c6e839d19958cb4f541ee1f78621140098f7.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# loading file https://huggingface.co/pysentimiento/robertuito-sentiment-analysis/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/4fdf9a5a8e0a6023e1a9cdef62921158c3db9545e73f8dc0f46340a21bbb64d5.50a2bcf7668df2ff5a82b7b0455533bb4c0db21e6e33565fa20fd7dc8a3be740
# loading configuration file https://huggingface.co/pysentimiento/robertuito-sentiment-analysis/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/034fd09e9530137fb6e6c042529972a92619fb02df8b40e7a4cfc50090943c46.98e658c5b8878c67807e3287b07db9608dbd08a5b69ce09979c447190bbe8077
# Model config RobertaConfig {
#   "_name_or_path": "pysentimiento/robertuito-sentiment-analysis",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "NEG",
#     "1": "NEU",
#     "2": "POS"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "NEG": 0,
#     "NEU": 1,
#     "POS": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 30002
# }
#
# loading weights file https://huggingface.co/pysentimiento/robertuito-sentiment-analysis/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/46eaf2275c70a984feed87be9019d2c427e10e13e4498d391bedffc0c61b4991.01d3c05bd9b3f5c750a6a897fc7bc380ac6c30347fa348718ca5ed37b03fdd46
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at pysentimiento/robertuito-sentiment-analysis.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
p1 = asentiment.predict("Antes que nada fue muy difícil poder comprarla a buen precio directamente con Amazon ya que se agota en pocos minutos, pero al fin se pudo y llegó mucho antes de la fecha indicada; vale totalmente la pena y llegó en buen estado tanto la figura como su caja, tiene un gran detalle, esculpido, gran articulación y buenos accesorios. Es altamente recomendable para todo fan de Dragon Ball y Gokú, si la ven a buen precio no duden en comprarla")

# %%
p1.output
# Out:
# 'POS'

# %%
pemotions = create_analyzer(task="emotion", lang='es')
# Out:
# https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmptoml0rp6
# Downloading:   0%|          | 0.00/334 [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/e5b58eb4110c09192df285dc3f632cae9b9474d810bb489a651effa5ddb2e2e9.50a2bcf7668df2ff5a82b7b0455533bb4c0db21e6e33565fa20fd7dc8a3be740
# creating metadata file for /root/.cache/huggingface/transformers/e5b58eb4110c09192df285dc3f632cae9b9474d810bb489a651effa5ddb2e2e9.50a2bcf7668df2ff5a82b7b0455533bb4c0db21e6e33565fa20fd7dc8a3be740
# https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpsrqky5nh
# Downloading:   0%|          | 0.00/838k [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/493237802ea94d02bfc7907883a3298b35a6cbd8d813fd11630c8c5056826a45.0843b07596b388e054bae078721182b4846b9e28a7bbf04d7079b274f8613ae3
# creating metadata file for /root/.cache/huggingface/transformers/493237802ea94d02bfc7907883a3298b35a6cbd8d813fd11630c8c5056826a45.0843b07596b388e054bae078721182b4846b9e28a7bbf04d7079b274f8613ae3
# https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpx9_dr54h
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/d36fe9b59af3e679efca2cfa00cffbc44be132ebc5ef39a61d32f5e60ee37ba2.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# creating metadata file for /root/.cache/huggingface/transformers/d36fe9b59af3e679efca2cfa00cffbc44be132ebc5ef39a61d32f5e60ee37ba2.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# loading file https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/493237802ea94d02bfc7907883a3298b35a6cbd8d813fd11630c8c5056826a45.0843b07596b388e054bae078721182b4846b9e28a7bbf04d7079b274f8613ae3
# loading file https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/d36fe9b59af3e679efca2cfa00cffbc44be132ebc5ef39a61d32f5e60ee37ba2.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# loading file https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/e5b58eb4110c09192df285dc3f632cae9b9474d810bb489a651effa5ddb2e2e9.50a2bcf7668df2ff5a82b7b0455533bb4c0db21e6e33565fa20fd7dc8a3be740
# https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmprtufeo_x
# Downloading:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/67cf0b22b25292bb1a3e1332f686c3c8cef2a203f1d7bccc6e801f16f7ae6e87.2e7a6ee7286c198ff851af16b0340004d73c5e8977413611e574ff14b9f7ff85
# creating metadata file for /root/.cache/huggingface/transformers/67cf0b22b25292bb1a3e1332f686c3c8cef2a203f1d7bccc6e801f16f7ae6e87.2e7a6ee7286c198ff851af16b0340004d73c5e8977413611e574ff14b9f7ff85
# loading configuration file https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/67cf0b22b25292bb1a3e1332f686c3c8cef2a203f1d7bccc6e801f16f7ae6e87.2e7a6ee7286c198ff851af16b0340004d73c5e8977413611e574ff14b9f7ff85
# Model config RobertaConfig {
#   "_name_or_path": "pysentimiento/robertuito-emotion-analysis",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "others",
#     "1": "joy",
#     "2": "sadness",
#     "3": "anger",
#     "4": "surprise",
#     "5": "disgust",
#     "6": "fear"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "anger": 3,
#     "disgust": 5,
#     "fear": 6,
#     "joy": 1,
#     "others": 0,
#     "sadness": 2,
#     "surprise": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 30002
# }
#
# https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpakh0_sd4
# Downloading:   0%|          | 0.00/415M [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/2f1a9c49582b07d3a39d108c5f099e762035431ed1169b22bb2d38fc3bfae48a.7d53b944be3007f8a318a47e5ce75f52dca2d342065e83317d1134583696cf31
# creating metadata file for /root/.cache/huggingface/transformers/2f1a9c49582b07d3a39d108c5f099e762035431ed1169b22bb2d38fc3bfae48a.7d53b944be3007f8a318a47e5ce75f52dca2d342065e83317d1134583696cf31
# loading weights file https://huggingface.co/pysentimiento/robertuito-emotion-analysis/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/2f1a9c49582b07d3a39d108c5f099e762035431ed1169b22bb2d38fc3bfae48a.7d53b944be3007f8a318a47e5ce75f52dca2d342065e83317d1134583696cf31
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at pysentimiento/robertuito-emotion-analysis.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
p1 = pemotions.predict("Antes que nada fue muy difícil poder comprarla a buen precio directamente con Amazon ya que se agota en pocos minutos, pero al fin se pudo y llegó mucho antes de la fecha indicada; vale totalmente la pena y llegó en buen estado tanto la figura como su caja, tiene un gran detalle, esculpido, gran articulación y buenos accesorios. Es altamente recomendable para todo fan de Dragon Ball y Gokú, si la ven a buen precio no duden en comprarla")

# %%
p1
# Out:
# AnalyzerOutput(output=joy, probas={joy: 0.723, others: 0.247, surprise: 0.015, sadness: 0.007, anger: 0.003, fear: 0.002, disgust: 0.002})

# %% [markdown]
# # huggingface:
# Hugging Face, una empresa que creó por primera vez una aplicación de chat para adolescentes aburridos, ofrece tecnologías de PNL de código abierto y, el año pasado, recaudó 15 millones de dólares para crear una biblioteca de PNL definitiva. Desde su aplicación de chat hasta el día de hoy, Hugging Face ha podido desarrollar rápidamente su experiencia en el procesamiento del lenguaje.
#
# [huggingface](https://huggingface.co/)

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.8.1+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torch-1.8.1%2Bcu111-cp37-cp37m-linux_x86_64.whl (1982.2 MB)
#      |█████████████▌                  | 834.1 MB 1.4 MB/s eta 0:14:01tcmalloc: large alloc 1147494400 bytes == 0x3981e000 @  0x7f17e04f5615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
#      |█████████████████               | 1055.7 MB 1.3 MB/s eta 0:12:21tcmalloc: large alloc 1434370048 bytes == 0x7de74000 @  0x7f17e04f5615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
#      |█████████████████████▋          | 1336.2 MB 781 kB/s eta 0:13:47tcmalloc: large alloc 1792966656 bytes == 0x2ca6000 @  0x7f17e04f5615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
#      |███████████████████████████▎    | 1691.1 MB 1.2 MB/s eta 0:04:04tcmalloc: large alloc 2241208320 bytes == 0x6da8e000 @  0x7f17e04f5615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
#      |████████████████████████████████| 1982.2 MB 1.2 MB/s eta 0:00:01tcmalloc: large alloc 1982177280 bytes == 0xf33f0000 @  0x7f17e04f41e7 0x4a3940 0x4a39cc 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x593dd7 0x511e2c 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9
# tcmalloc: large alloc 2477727744 bytes == 0x16964a000 @  0x7f17e04f5615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x549576 0x593fce 0x511e2c 0x593dd7 0x511e2c 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576
#      |████████████████████████████████| 1982.2 MB 2.7 kB/s
# Collecting torchvision==0.9.1+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torchvision-0.9.1%2Bcu111-cp37-cp37m-linux_x86_64.whl (17.6 MB)
#      |████████████████████████████████| 17.6 MB 48.4 MB/s
# Collecting torchaudio===0.8.1
#   Downloading torchaudio-0.8.1-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 5.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1+cu111) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1+cu111) (4.1.1)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.9.1+cu111) (7.1.2)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.11.0+cu113
#     Uninstalling torchaudio-0.11.0+cu113:
#       Successfully uninstalled torchaudio-0.11.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.8.1+cu111 which is incompatible.
# pysentimiento 0.3.2 requires torch<2.0.0,>=1.9.0, but you have torch 1.8.1+cu111 which is incompatible.
# Successfully installed torch-1.8.1+cu111 torchaudio-0.8.1 torchvision-0.9.1+cu111

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# %%
tokenizer = AutoTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
# Out:
# https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpqbzxotng
# Downloading:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# storing https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/4d1409805ace1b4cc209352f82a0f0c59a015433d0a58e655394ffe7bbb755e9.13a045cad07359e6844c4f487af8e6323ad2308cac6357692d2359f1a9711443
# creating metadata file for /root/.cache/huggingface/transformers/4d1409805ace1b4cc209352f82a0f0c59a015433d0a58e655394ffe7bbb755e9.13a045cad07359e6844c4f487af8e6323ad2308cac6357692d2359f1a9711443
# https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp401j05b1
# Downloading:   0%|          | 0.00/953 [00:00<?, ?B/s]
# storing https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/d9226eeac7b8b96d83ebc327cdd670490866d8c999505c1f83b6ef206ccb1604.a34960b447312b0727cb670d710444fcb41a6156eddcba062a19b3fc05d95251
# creating metadata file for /root/.cache/huggingface/transformers/d9226eeac7b8b96d83ebc327cdd670490866d8c999505c1f83b6ef206ccb1604.a34960b447312b0727cb670d710444fcb41a6156eddcba062a19b3fc05d95251
# loading configuration file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/d9226eeac7b8b96d83ebc327cdd670490866d8c999505c1f83b6ef206ccb1604.a34960b447312b0727cb670d710444fcb41a6156eddcba062a19b3fc05d95251
# Model config BertConfig {
#   "_name_or_path": "nlptown/bert-base-multilingual-uncased-sentiment",
#   "_num_labels": 5,
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "finetuning_task": "sentiment-analysis",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "1 star",
#     "1": "2 stars",
#     "2": "3 stars",
#     "3": "4 stars",
#     "4": "5 stars"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "1 star": 0,
#     "2 stars": 1,
#     "3 stars": 2,
#     "4 stars": 3,
#     "5 stars": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 105879
# }
#
# https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpp0coaowu
# Downloading:   0%|          | 0.00/851k [00:00<?, ?B/s]
# storing https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/d893db6e58fdc9c39ecb49aaba0fc940780c179e1fff5bfe27e322e1599c191f.92022aa29ab6663b0b4254744f28ab43e6adf4deebe0f26651e6c61f28f69d8b
# creating metadata file for /root/.cache/huggingface/transformers/d893db6e58fdc9c39ecb49aaba0fc940780c179e1fff5bfe27e322e1599c191f.92022aa29ab6663b0b4254744f28ab43e6adf4deebe0f26651e6c61f28f69d8b
# https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpzbyr1lub
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# storing https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/ed85e7bfaa7dfcf9924004400478a6426fcab28d3e427960549371a1729115d1.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# creating metadata file for /root/.cache/huggingface/transformers/ed85e7bfaa7dfcf9924004400478a6426fcab28d3e427960549371a1729115d1.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/d893db6e58fdc9c39ecb49aaba0fc940780c179e1fff5bfe27e322e1599c191f.92022aa29ab6663b0b4254744f28ab43e6adf4deebe0f26651e6c61f28f69d8b
# loading file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/ed85e7bfaa7dfcf9924004400478a6426fcab28d3e427960549371a1729115d1.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/4d1409805ace1b4cc209352f82a0f0c59a015433d0a58e655394ffe7bbb755e9.13a045cad07359e6844c4f487af8e6323ad2308cac6357692d2359f1a9711443
# loading configuration file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/d9226eeac7b8b96d83ebc327cdd670490866d8c999505c1f83b6ef206ccb1604.a34960b447312b0727cb670d710444fcb41a6156eddcba062a19b3fc05d95251
# Model config BertConfig {
#   "_name_or_path": "nlptown/bert-base-multilingual-uncased-sentiment",
#   "_num_labels": 5,
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "finetuning_task": "sentiment-analysis",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "1 star",
#     "1": "2 stars",
#     "2": "3 stars",
#     "3": "4 stars",
#     "4": "5 stars"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "1 star": 0,
#     "2 stars": 1,
#     "3 stars": 2,
#     "4 stars": 3,
#     "5 stars": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 105879
# }
#
# loading configuration file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/d9226eeac7b8b96d83ebc327cdd670490866d8c999505c1f83b6ef206ccb1604.a34960b447312b0727cb670d710444fcb41a6156eddcba062a19b3fc05d95251
# Model config BertConfig {
#   "_name_or_path": "nlptown/bert-base-multilingual-uncased-sentiment",
#   "_num_labels": 5,
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "finetuning_task": "sentiment-analysis",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "1 star",
#     "1": "2 stars",
#     "2": "3 stars",
#     "3": "4 stars",
#     "4": "5 stars"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "1 star": 0,
#     "2 stars": 1,
#     "3 stars": 2,
#     "4 stars": 3,
#     "5 stars": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 105879
# }

# %%
modelo  = AutoModelForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
# Out:
# loading configuration file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/d9226eeac7b8b96d83ebc327cdd670490866d8c999505c1f83b6ef206ccb1604.a34960b447312b0727cb670d710444fcb41a6156eddcba062a19b3fc05d95251
# Model config BertConfig {
#   "_name_or_path": "nlptown/bert-base-multilingual-uncased-sentiment",
#   "_num_labels": 5,
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "finetuning_task": "sentiment-analysis",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "1 star",
#     "1": "2 stars",
#     "2": "3 stars",
#     "3": "4 stars",
#     "4": "5 stars"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "1 star": 0,
#     "2 stars": 1,
#     "3 stars": 2,
#     "4 stars": 3,
#     "5 stars": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 105879
# }
#
# https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpp9jy63fp
# Downloading:   0%|          | 0.00/638M [00:00<?, ?B/s]
# storing https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/c3020f16ae496cb8ba53cdb83e08cca88c008e5c4263884ecdc4a8a6000e8751.2da3f39deb1fb7ac0e8bd6c41b5ded28013a75c0d779d283a57e6b0fe34d4091
# creating metadata file for /root/.cache/huggingface/transformers/c3020f16ae496cb8ba53cdb83e08cca88c008e5c4263884ecdc4a8a6000e8751.2da3f39deb1fb7ac0e8bd6c41b5ded28013a75c0d779d283a57e6b0fe34d4091
# loading weights file https://huggingface.co/nlptown/bert-base-multilingual-uncased-sentiment/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/c3020f16ae496cb8ba53cdb83e08cca88c008e5c4263884ecdc4a8a6000e8751.2da3f39deb1fb7ac0e8bd6c41b5ded28013a75c0d779d283a57e6b0fe34d4091
# All model checkpoint weights were used when initializing BertForSequenceClassification.
#
# All the weights of BertForSequenceClassification were initialized from the model checkpoint at nlptown/bert-base-multilingual-uncased-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForSequenceClassification for predictions without further training.

# %%
tokens_ = tokenizer.encode("Antes que nada fue muy difícil poder comprarla a buen precio directamente con Amazon ya que se agota en pocos minutos, pero al fin se pudo y llegó mucho antes de la fecha indicada; vale totalmente la pena y llegó en buen estado tanto la figura como su caja, tiene un gran detalle, esculpido, gran articulación y buenos accesorios. Es altamente recomendable para todo fan de Dragon Ball y Gokú, si la ven a buen precio no duden en comprarla",
                           return_tensors='pt')

# %%
tokenizer.decode(101)
# Out:
# '[CLS]'

# %%
tokens_
# Out:
# tensor([[  101, 12698, 10126, 21188, 10565, 13653, 28299, 13129, 62530, 10335,
#            143, 40362, 77273, 35903, 10173, 24432, 10593, 10126, 10128, 30526,
#          10211, 10109, 33424, 22955,   117, 10791, 10161, 11907, 10128, 30934,
#            167, 20027, 23505, 12698, 10102, 10106, 23633, 21168, 10250,   132,
#          23172, 28743, 10106, 20685,   167, 20027, 10109, 40362, 10714, 12999,
#          10106, 17374, 10245, 10192, 51106,   117, 12687, 10119, 11121, 10274,
#          30791,   117, 10153, 66266, 91402,   117, 11121, 33005, 31148, 10985,
#            167, 13920, 31167, 21336,   119, 10153, 58763, 44909, 48290, 46296,
#          10301, 10239, 12692, 10923, 10102, 17566, 14918,   167, 89699,   117,
#          10193, 10106, 22712,   143, 40362, 77273, 10181, 60537, 10142, 10109,
#          62530, 10335,   102]])

# %%
prediccion = modelo(tokens_)

# %%
prediccion.logits
# Out:
# tensor([[-2.5609, -2.0123, -0.8919,  1.6717,  3.0927]],
#        grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## ¿Cómo lo aplicas a tus datos?

# %% [markdown]
# # WordTree
# Esta biblioteca de Python genera diagramas de árbol de palabras. Los diagramas de árbol de palabras muestran la frecuencia con la que aparecen diferentes frases en un corpus que contienen una palabra clave específica.

# %%
# !pip install wordtree
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wordtree
#   Downloading wordtree-0.1.0-py3-none-any.whl (2.8 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from wordtree) (0.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from wordtree) (1.3.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from wordtree) (4.64.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->wordtree) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->wordtree) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->wordtree) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->wordtree) (1.15.0)
# Installing collected packages: wordtree
# Successfully installed wordtree-0.1.0

# %%
textos = ["I like natural language processing", " drink natural juice", "natural born killer" ]

# %%
import wordtree

# %%
from IPython.display import Image

# %%
treeImage = wordtree.search_and_draw(corpus=textos, keyword='natural')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
treeImage.render()
# Out:
# 'natural.gv.png'

# %%
Image('natural.gv.png')

# %%
print()

# %% [markdown]
# # t-distributed stochastic neighbor embedding (t-SNE):
# ## es un método estadístico para visualizar datos de alta dimensión al dar a cada punto de datos una ubicación en un mapa bidimensional o tridimensional.

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def visualizar_modeloo_TSNE(modelo,perplejidad, dimensiones, iteraciones):
    etiquetas = []
    tokens = []

    # agregar el vocabulario y configurar t-SNE
    for palabra in modelo.wv.vocab:
        tokens.append(modelo[palabra])
        etiquetas.append(palabra)

    tsne_modelo = TSNE(perplexity= perplejidad, n_components= dimensiones, n_iter=iteraciones, verbose=1)
    nuevos_valores = tsne_modelo.fit_transform(tokens)
    x = []
    y = []
    for value in nuevos_valores:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(32, 32)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(etiquetas[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
visualizar_modeloo_TSNE(modelow2v, 5, 2, 300)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 879 samples in 0.001s...
# [t-SNE] Computed neighbors for 879 samples in 0.121s...
# [t-SNE] Computed conditional probabilities for sample 879 / 879
# [t-SNE] Mean sigma: 0.006799
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.229172
# [t-SNE] KL divergence after 300 iterations: 2.038222

# %% [markdown]
# # Reto de Analítica de Textos.
# 1. Crear o utilizar un corpus para realizar operaciones de analítica.
# 2. Realizar el pipeline básico
# 3. Mostrar frecuencias de palabras y wordcloud.
# 4. Usar Pysentimiento o Hugginface para obtener sentimientos.
#
# ¿Qué les deja la analítica de textos para el corpus que procesan?
#
# 5. Opcional:
#     * Visualizar con T-SNE
#     * Crear un clasificador binario de textos.
